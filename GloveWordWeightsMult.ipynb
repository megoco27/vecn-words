# %%
from scipy import spatial
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import random
import time
import math
tokenizer = RegexpTokenizer(r'\w+')

# %% [markdown]
# ## Now with our data

# %%
ItemsDF = pd.read_excel('Items_IS.xlsx') #header=None, skiprows=1)
#df.head(10)
#dfd = df.head(10)
dfd = ItemsDF[['ItemId','VariableId','Text']]

# %%
(17838*(17838-1))/2
# Out:
# 159088203.0

# %% [markdown]
# ## Create a new column in your existing dataframe

# %% [markdown]
# ## Import the GloVE

# %%
import pandas as pd
import csv

words = pd.read_table('glove.840B.300d.txt', sep=" ", index_col=0, header=None, quoting=csv.QUOTE_NONE)

# %% [markdown]
# ## Make the vec function

# %%
def vec(w):
    return words.loc[w].as_matrix()

# %% [markdown]
# ## Create an overlapping dictionary

# %%
import re
all_words = [word for sentence in ItemsDF['Text'] for word in re.split('\W', sentence)]
unique = (set(all_words))

# %%
all_words1 = [word.lower() for sentence in ItemsDF['Text'] for word in re.split('\W', sentence)]
lower = (set(all_words))

# %%
glove_words = list(words.index.values)

# %%
a = unique
b = glove_words
c = []
for e in b:
    if e in a:
        c.append(e)

# %%
dict1 = {}
for word in c:
    vword = vec(word)
    vector = {word : vword }
    dict1.update(vector)

# %%
Embeddings1 = dict1

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ## Weighted Words

# %%
idf= pd.read_csv('TDNews.csv')
idf.head(5)
# Out:
#    TermID   TermName  StemID  StemName  DocumentID  Frequency
# 0   74169  committee   64277  committe         846          1
# 1   72262         co   62921        co         846          1
# 2   79071      craig   67593     craig         846          3
# 3   95581       easy   79854      easi          91          1
# 4   93002    drastic   77822   drastic         846          1

# %% [markdown]
# ## n and N

# %%
idff = idf.groupby(['TermName','TermID'], as_index = False, sort = False)['DocumentID'].count()
df = idf.groupby(['DocumentID'],as_index = False, sort = False)['Frequency'].count().count()
df
# Out:
# DocumentID    161754
# Frequency     161754
# dtype: int64

# %% [markdown]
# ### Log2(N/n)

# %%
var = df['DocumentID']
var
idff['weight'] = idff['DocumentID'].apply(lambda x: math.log((var/x),2))

# %%
idff.head(10)
# Out:
#        TermName  TermID  DocumentID    weight
# 0     committee   74169       10938  3.886381
# 1            co   72262       37710  2.100782
# 2         craig   79071        2886  5.808586
# 3          easy   95581        9699  4.059822
# 4       drastic   93002         705  7.841962
# 5      continue   76491       22324  2.857134
# 6      employee   98642        9532  4.084879
# 7  experimental  103047        1101  7.198843
# 8          hard  125402       22819  2.825494
# 9       denying   86587        1090  7.213329

# %% [markdown]
# ## Now make the dictionary
# #### Update the dictionary with unfound words as the keys and AVG as the values

# %%
print((idff['weight']).mean())
print((idff['weight']).median())
# Out:
# 15.372384792109694
# 16.30344186337058

# %%
weightdict =  dict(zip(idff.TermName,idff.iloc[:,3]))
a1 = unique
b1 = weightdict
c1 = []
for e in a1:
    if e not in b1:
        c1.append(e)

# %%
tempmean = 0
for word in all_words1:
    if word in weightdict.keys():
        tempmean = tempmean + weightdict[word]
mean = tempmean/len(all_words1)

# %%
for word in c1:
    weightdict.update({word:mean})

# %%
weightdict
# Out:
# {'committee': 3.8863805166102887,
#  'co': 2.1007823333415523,
#  'craig': 5.80858627887938,
#  'easy': 4.059821570523337,
#  'drastic': 7.841962416084423,
#  'continue': 2.8571339323202327,
#  'employee': 4.0848786271803075,
#  'experimental': 7.1988431098062104,
#  'hard': 2.8254939142213593,
#  'denying': 7.21332944370629,
#  'credit': 1.15127587715498,
#  'commerce': 4.481667881400011,
#  'expert': 5.2841986467669715,
#  'could': 1.098641495535761,
#  'facts': 5.730268078684093,
#  'greatest': 5.786264610681037,
#  'has': 0.36621748866976084,
#  'husband': 5.541890630926099,
#  'it': 0.14691433541401436,
#  'changes': 3.4843605007212894,
#  'fairly': 5.438481948227978,
#  'didnt': 2.603706758206076,
#  'do': 1.4781849118565544,
#  'companies': 1.4998909012103703,
#  'industry': 1.9620620347823041,
#  'harvard': 5.774499448305684,
#  'conscience': 8.945889858752494,
#  'even': 1.5703735647254293,
#  'consumers': 3.077180210055075,
#  'her': 2.9225073732821047,
#  'insurers': 6.36533253715134,
#  'lower': 3.1424674884426427,
#  'copyright': 0.03297314647216708,
#  'he': 0.6795746586686652,
#  'iii': 5.813092357631293,
#  'incredibly': 7.091553568824574,
#  'just': 1.4521564246709473,
#  'limited': 4.223623778158224,
#  'example': 3.256147510587575,
#  'mailer': 11.153694743865897,
#  'county': 3.8321476927033067,
#  'defined': 6.621325098420505,
#  'democratic': 6.033146536898538,
#  'denied': 4.669311490277252,
#  'expensive': 4.239878252785588,
#  'director': 2.4619757952163823,
#  'huge': 3.5399182466809886,
#  'involve': 6.003661460512039,
#  'maximum': 6.087908863624923,
#  'janet': 7.191002356589027,
#  'favorite': 5.2106847224507264,
#  'push': 4.44429536794462,
#  'erisa': 11.39655126776206,
#  'offer': 2.7144930430558976,
#  'jamie': 7.1780283928872635,
#  'known': 2.7417362559151,
#  'due': 4.232482386443013,
#  'exceptions': 7.877177108668481,
#  'exclusion': 9.54855436120711,
#  'lawyers': 3.974626712002001,
#  'external': 7.123532773355644,
#  'cost': 2.4981010349541943,
#  'favor': 4.693109061459444,
#  'deputy': 5.679103318057594,
#  'message': 4.0491513582535195,
#  'from': 0.27857274522504427,
#  'company': 0.2766374823097909,
#  'effective': 4.803097894100175,
#  'congress': 4.509838554091172,
#  'followed': 4.350518653007852,
#  'forcing': 5.712387089333799,
#  'mich': 5.669992488657086,
#  'feel': 3.5998626732979147,
#  'family': 3.237773295977942,
#  'goodriches': 17.30344186337058,
#  'scramble': 7.692417066063227,
#  'introspection': 12.055514349926995,
#  'move': 2.534068880399547,
#  'helpful': 7.0042338449832995,
#  'pentium': 7.123532773355644,
#  'hmo': 8.50578033751682,
#  'the': 0.0037240540039879732,
#  'judgment': 5.846574124990235,
#  'consumer': 3.2297186822135604,
#  'insiders': 6.179320551541391,
#  'firm': 2.2108085855150557,
#  'pointed': 5.235671405922755,
#  'hottest': 7.1173276238289365,
#  'to': 0.016541228106118935,
#  'd': 2.4376119521971917,
#  'necessary': 4.70632043458101,
#  'its': 0.32269980068931076,
#  'network': 2.6377728500110154,
#  'keep': 2.678817732008224,
#  'buster': 10.30344186337058,
#  'david': 2.9951739457409032,
#  'died': 5.0484132935518495,
#  'increasing': 4.581701809157532,
#  'postcards': 10.457951812426204,
#  'developing': 4.624181703653788,
#  'ceo': 3.445849577673053,
#  'experts': 3.9128698258990733,
#  'large': 2.6616158913287524,
#  'point': 2.7159573216876676,
#  'close': 2.3643677541885904,
#  'mirror': 4.52023897330619,
#  'mobilize': 10.733586255039631,
#  'lawsuits': 4.6887320192553705,
#  'reserved': 4.270190949271859,
#  'million': 0.9201763313666604,
#  'multiply': 9.787742025086535,
#  'nationwide': 4.8223992884368245,
#  'legislation': 5.660487639890246,
#  'most': 1.3161334340310336,
#  'look': 2.678303819538441,
#  'front': 3.7085341403072447,
#  'general': 2.3833681942245626,
#  'nation': 2.878225960071194,
#  'fears': 5.880325953223478,
#  'not': 0.48029856894985035,
#  'obtain': 5.924605150159964,
#  'give': 2.594519652057132,
#  'more': 0.5704000529618529,
#  'outrage': 7.758477430581342,
#  'feature': 4.805340619375727,
#  'employers': 6.12664538522298,
#  'group': 1.8889878472194226,
#  'keeps': 5.596514223753176,
#  'side': 3.417268991350996,
#  'court': 2.7386969319463357,
#  'practices': 4.13555335018993,
#  'enormously': 8.366803924368009,
#  'los': 2.521160267222481,
#  'kinds': 5.558187721413322,
#  'they': 0.6220936281967714,
#  'hope': 3.852488398657586,
#  'loss': 3.0936077690980106,
#  'university': 3.209364177698674,
#  'have': 0.40484047596664086,
#  'i': 1.1816250798196253,
#  'put': 2.324508011154209,
#  'implemented': 7.368276813766884,
#  'process': 3.313692587908446,
#  'obviously': 5.03577732586946,
#  'federal': 2.25482727769393,
#  'jury': 4.923792745610545,
#  'use': 2.1847440713380535,
#  'americans': 4.680703645499436,
#  'punitive': 7.462663939775525,
#  'clot': 10.103769518534214,
#  'largest': 2.0988325126611596,
#  'compensation': 4.856875454304511,
#  'something': 2.777554065243754,
#  'john': 2.5497550193170597,
#  'suspicion': 7.972524985255961,
#  'of': 0.016523184381285652,
#  'brought': 3.6991202994933063,
#  'ferrets': 14.133516861928266,
#  'legal': 3.418317496266479,
#  'lawsuit': 3.9274521741406776,
#  'no': 1.059840163990932,
#  'during': 1.9879738449141258,
#  'opportunity': 3.8324017777763286,
#  'system': 2.57584043620135,
#  'executive': 1.4577313086366954,
#  'daschle': 10.174158846425613,
#  'many': 1.4917159721650275,
#  'fiddling': 10.470551849205837,
#  'on': 0.17758448050876932,
#  'referring': 5.072220682659394,
#  'outside': 3.2073856241896324,
#  'nothing': 3.400313186558259,
#  'including': 1.6777330203061134,
#  'new': 0.3782699367368757,
#  'first': 1.0756003284871993,
#  'option': 4.516559669705881,
#  'owned': 3.434812195157922,
#  'recent': 2.4111836674524185,
#  'right': 2.2462962464598815,
#  'save': 4.404273787236256,
#  'only': 1.3450930608321183,
#  'or': 0.6165036917001913,
#  'is': 0.18420688120291417,
#  'organization': 4.401443677702083,
#  'physicians': 6.825683596926691,
#  'fish': 6.52536473383522,
#  'law': 3.001088536939376,
#  'then': 1.872793306672358,
#  'riverside': 8.141050534613674,
#  'was': 0.3745071726291577,
#  'legislative': 6.750772765856308,
#  'for': 0.07756603916995197,
#  'think': 2.054143195676959,
#  'probably': 3.081024283648568,
#  'record': 3.1659703600186186,
#  'get': 1.5446200793801792,
#  'said': 0.20388857890370413,
#  'procedures': 5.965819961378072,
#  'several': 2.046238199999377,
#  'solid': 5.032854522923068,
#  'percent': 1.4691930418813917,
#  'provide': 3.024919807588583,
#  'republicans': 6.824672243894815,
#  'redress': 10.589196345704456,
#  'force': 3.3770532010208902,
#  'former': 2.1959386968906762,
#  'reform': 6.223290553756492,
#  'up': 0.7612563758683968,
#  'may': 1.3874691454838306,
#  'securities': 3.034022933629482,
#  'well': 1.6860317947878494,
#  'searching': 6.47292665639374,
#  'such': 1.5510873528341511,
#  'what': 1.1894962630188566,
#  'that': 0.08806054264949495,
#  'fact': 3.184257550973431,
#  'public': 2.214363856198364,
#  'shareholder': 4.2658949094084,
#  'though': 2.380671654095915,
#  'when': 0.8888557171640683,
#  'you': 1.4792537866482176,
#  'money': 2.1997032831877004,
#  'graphical': 9.56873224314474,
#  'grievance': 9.928402432023654,
#  'sue': 6.066829663154828,
#  'had': 0.6565597530778347,
#  'verdicts': 8.928402432023654,
#  'wake': 5.366803924368009,
#  'avoid': 4.371596323186906,
#  'stinging': 9.561974876969433,
#  'world': 2.0561076853418503,
#  'heat': 5.804592656838854,
#  'there': 1.0612725810925638,
#  'hearst': 4.140893181170655,
#  'who': 0.7417064275206342,
#  'business': 1.327213393539505,
#  'shares': 2.0898439667379884,
#  'represents': 4.295713748738324,
#  'resulted': 5.453255025724804,
#  'schoolteacher': 10.384578626095983,
#  'way': 1.780737742572327,
#  'stop': 3.771451285242985,
#  'won': 3.6296911239325156,
#  'nelene': 16.30344186337058,
#  'officials': 2.365148719218889,
#  'ripe': 8.121047509966049,
#  'policy': 4.086392949814241,
#  'like': 1.3355401749552032,
#  'since': 1.6406900524742043,
#  'would': 0.6267960550808879,
#  'staff': 1.633449583754181,
#  'nintendo': 7.906837082188721,
#  'humana': 9.41469861447232,
#  'inexpensive': 7.2535933139200175,
#  'rare': 5.246804148257378,
#  'need': 2.541111736037443,
#  'vowed': 6.452473712388141,
#  'both': 1.9205139302451815,
#  'researcher': 6.5082138973419,
#  'independent': 3.7647679102879104,
#  'we': 0.8442824407719243,
#  'state': 2.2750609196807248,
#  'stomach': 7.594358050820235,
#  'inside': 4.077481336134417,
#  'rights': 3.316622099197128,
#  'another': 1.7893750963322597,
#  'san': 2.87789811208867,
#  'informed': 5.969168578063388,
#  'teresa': 9.390552527140617,
#  'about': 0.5932273487205696,
#  'bush': 4.597593519861633,
#  'this': 0.5253262227717564,
#  'williams': 5.226626266319748,
#  'ample': 7.4439070769879265,
#  'treatment': 4.783805610527366,
#  'appeal': 4.371780964518301,
#  'widow': 8.171584902761785,
#  'over': 1.0991764072337358,
#  'wrong': 4.1785128167681,
#  'basis': 4.579567644506679,
#  'internet': 2.6085943091307553,
#  'isnt': 3.4005015402423036,
#  'william': 4.011120230568539,
#  'faith': 5.811588767040904,
#  'constituent': 11.055514349926993,
#  'president': 1.621434863326472,
#  'jointed': 14.303441863370578,
#  'copy': 5.5573474796651166,
#  'lens': 8.831766648978535,
#  'sympathy': 8.103769518534214,
#  'course': 3.622642828797598,
#  'lets': 5.718949066394704,
#  '1999a': 8.314757176598413,
#  'after': 0.8713730660095748,
#  'profits': 3.562501657944682,
#  'fraud': 4.568520595665319,
#  'other': 0.7862184658509261,
#  'approval': 3.8377479275077584,
#  'whose': 2.907238481228886,
#  'trial': 3.935071820475904,
#  'gray': 5.793172192472401,
#  'writer': 2.4724810821767154,
#  'begin': 3.4764962129550936,
#  'left': 2.525621500532979,
#  'care': 3.632785614252139,
#  'going': 1.815444859605268,
#  'tend': 5.555668462843788,
#  'damages': 5.51472353068012,
#  'internal': 4.337477253098497,
#  'warning': 5.149256654105281,
#  'grounded': 8.417745490031184,
#  'lawyer': 3.8376204077268046,
#  'high': 1.7466664062439965,
#  'association': 3.966795838623207,
#  'healthcare': 6.343439931302498,
#  'managed': 4.745738849332811,
#  'them': 1.3712732577083016,
#  'hip': 6.549389495841655,
#  'avert': 8.627484830428829,
#  'reason': 3.5781821285333444,
#  'physical': 5.8404284499208865,
#  'with': 0.20080997451561056,
#  'these': 2.0224898979469272,
#  'amounts': 5.392424455573593,
#  'pick': 4.645230380618784,
#  'initial': 4.33477507017537,
#  'kindergarten': 9.659585673595853,
#  'repeatedly': 5.299221397052383,
#  'mass': 4.620886122290268,
#  'advocacy': 6.527008830925846,
#  'never': 2.6246216838465513,
#  'patient': 5.710984826102498,
#  'u': 2.2593893315692766,
#  'very': 2.0041265055955124,
#  'rate': 3.757391472652092,
#  'lineup': 5.760893601035367,
#  'critical': 4.461287978735707,
#  'say': 1.7187729095690445,
#  'changing': 4.722241281445622,
#  'component': 6.351428698481092,
#  'and': 0.024493370675761263,
#  'whole': 3.8627024403563057,
#  'will': 0.5357487920510347,
#  'develop': 4.31262878421697,
#  'based': 1.214695024898768,
#  'lollapalooza': 13.055514349926995,
#  'scene': 5.67956037335712,
#  'hailed': 7.1285161808699,
#  'prosecutor': 6.236007502614057,
#  'appropriations': 9.189699697321391,
#  'approving': 7.3290272735650515,
#  'multimillion': 6.951398437575146,
#  'retirement': 4.768652651890312,
#  'attorney': 3.494879833413054,
#  'some': 0.9980925807716308,
#  'by': 0.22681412946746937,
#  'long': 1.7571502596368351,
#  'their': 0.808289497148101,
#  'threat': 4.98602924960571,
#  'thursday': 3.0146478680956776,
#  'pass': 4.3590958292327455,
#  'place': 2.741378355878313,
#  'pending': 4.746935808698651,
#  'conservative': 5.707252107226169,
#  'dollar': 4.432884489044164,
#  'allowed': 3.900962691155615,
#  'review': 3.8944487840283997,
#  'measures': 5.475702214563622,
#  'representing': 5.106839736847408,
#  'bad': 3.462368980485802,
#  'seek': 4.367172005768369,
#  'carrier': 5.031103679211956,
#  'pete': 5.949192481425338,
#  'marilyn': 8.19753335479942,
#  'size': 3.6633099246059673,
#  'delaying': 7.668630813198861,
#  'still': 1.6229449782670213,
#  'number': 2.5565601972221748,
#  'last': 0.798995264220998,
#  'george': 4.150206524681166,
#  'others': 2.775964857310183,
#  'debate': 5.1906765814852625,
#  'hands': 4.36312826622461,
#  'wasnt': 3.6472404831760254,
#  'enjoyed': 5.9837697424235845,
#  'yucaipa': 10.795647223171883,
#  'employees': 2.4535481273492623,
#  'signed': 4.040759721008414,
#  'a': 0.02213663256752276,
#  'life': 3.1832039860286194,
#  'taking': 3.01097642842131,
#  'unauthorized': 7.464238075273634,
#  'uncomfortable': 7.371227111402193,
#  'aetna': 8.086696005175273,
#  'lawmakers': 5.7838056105273665,
#  'bill': 3.177382747299898,
#  'school': 3.263751677233494,
#  'ought': 6.467391508312509,
#  'webcams': 12.981513768483218,
#  'unfortunate': 7.011120230568539,
#  'broaden': 7.4896606721535415,
#  'expanded': 5.162292664933063,
#  '1999the': 5.954713709139501,
#  'an': 0.3466346682635678,
#  'expand': 4.238867490221435,
#  'hear': 4.6217642081608865,
#  'cannot': 4.350518653007852,
#  'into': 1.133399459882314,
#  'rock': 5.351792877465959,
#  'jan': 3.200072085978057,
#  'introduced': 4.493673734660165,
#  'run': 2.567780073904883,
#  'bobby': 7.179320551541392,
#  'second': 2.0474912433364687,
#  'serves': 5.304146476347168,
#  'vigorously': 6.950295037872496,
#  'deep': 4.650820928732415,
#  'which': 0.4584419415428213,
#  'act': 4.1440435155175415,
#  'as': 0.28022896877492276,
#  'exchange': 2.676021976372532,
#  'similarly': 6.295713748738325,
#  'drafted': 7.35946194902684,
#  'amp': 1.9407103586356618,
#  'edward': 5.283851135012698,
#  'stock': 1.7615285168701786,
#  'driving': 4.810086741875672,
#  'all': 0.9315461335551454,
#  'facing': 4.781105542457274,
#  'inc': 1.7851575419164771,
#  'johnson': 4.709117259445732,
#  'saved': 6.288026810983891,
#  'variety': 4.788481300040396,
#  'grounds': 6.409382017096556,
#  'send': 4.502946362903766,
#  'angeles': 2.5336556635291876,
#  'week': 1.6609952438505253,
#  'believed': 4.59802546448788,
#  'smashing': 9.88558934848468,
#  'fate': 6.181908346030546,
#  'however': 2.5771172517202436,
#  'workers': 3.255551126766744,
#  'bernardino': 9.103769518534214,
#  'case': 2.4072513894849417,
#  'government': 2.73893507903187,
#  '1998the': 5.646123413789292,
#  'can': 1.1513353088726477,
#  'liz': 8.171584902761785,
#  'one': 0.6907173203239512,
#  'advance': 5.264865760601789,
#  'certain': 3.6754520790548746,
#  'tribjobs': 17.30344186337058,
#  'might': 2.1825965098981697,
#  'walking': 6.118566520462294,
#  'book': 4.355439732392909,
#  'transplant': 8.977012376248275,
#  'ability': 3.8345633095511524,
#  'ago': 2.013206974052418,
#  'cancer': 5.43461930859558,
#  'challenge': 4.146884710170608,
#  'legitimate': 6.263152142344862,
#  'approached': 6.033730742227797,
#  'allowing': 4.747894091723515,
#  'mistake': 5.748373472037242,
#  'poor': 3.9327544565633614,
#  'at': 0.2519779918044266,
#  'same': 1.978980007393261,
#  'property': 4.418889729383344,
#  'card': 4.487658319242394,
#  'senator': 6.273464516781,
#  'denial': 8.146094928007736,
#  'central': 4.501531460473549,
#  'monica': 6.632785614252139,
#  'income': 3.2077151947315317,
#  'confident': 5.053735806400875,
#  'different': 2.9393756230651307,
#  'santa': 4.803595976287374,
#  'comment': 2.850878858538291,
#  'simply': 3.971685151115108,
#  'citizens': 5.863610979389186,
#  'worth': 3.230806782258268,
#  'bandwidth': 8.062650531208622,
#  'corporation': 2.80328465476939,
#  'acted': 6.19491740659241,
#  'community': 3.8284684789794325,
#  'where': 1.7856187173322537,
#  'spokesman': 2.430574636584004,
#  'conceived': 7.894050927232876,
#  'besides': 5.326877739955249,
#  'day': 2.0191961135409087,
#  'without': 2.4404171531336925,
#  'able': 2.8872381053107077,
#  'does': 2.463992003356258,
#  'directly': 4.175769896331597,
#  'currently': 4.366803924368009,
#  'allows': 4.411848000936922,
#  'amend': 8.977012376248275,
#  'arose': 7.772060402854267,
#  'delayed': 5.5188070178130575,
#  'been': 0.7496026116520739,
#  'assn': 6.616066179933112,
#  'following': 4.08563558980898,
#  'getting': 2.9498814804550477,
#  'signature': 6.657783430961868,
#  'great': 2.892858014732736,
#  'entire': 4.132734362022503,
#  'dualaction': 17.30344186337058,
#  'nonetheless': 6.067427671470495,
#  'friction': 8.67044666622762,
#  'owes': 7.414698614472319,
#  'people': 1.5197529719403375,
#  'downloading': 7.43770859251882,
#  'pockets': 6.592635429671228,
#  'brings': 5.542721915904956,
#  'protect': 4.647464000883637,
#  'led': 3.100323314870964,
#  'marrow': 9.963591860485954,
#  'every': 2.5648745555296433,
#  'found': 2.8261262869153136,
#  'oppression': 11.420798814008737,
#  'infringement': 7.029646264156314,
#  'in': 0.017019469061985548,
#  'behavior': 5.412037866705556,
#  'year': 0.6223956626547386,
#  'wife': 4.5043626543415725,
#  'security': 4.159261624311656,
#  'me': 2.837556652062879,
#  'organizations': 5.096122436912774,
#  'expecting': 5.803097894100175,
#  'relief': 5.8501712293599555,
#  'courtroom': 6.272085267114869,
#  'join': 4.827455172499925,
#  'executives': 2.3419921689723826,
#  'rules': 3.9347989961481455,
#  'expense': 5.21332944370629,
#  'senate': 5.230304480260196,
#  'mere': 6.6434459709406015,
#  'behind': 3.1420737505397898,
#  'bloomberg': 3.3029136293837578,
#  'perceived': 6.693339800370914,
#  'publishing': 3.742631394642638,
#  'j': 2.8597212627140016,
#  'investors': 2.695302572527137,
#  'file': 4.307851351004279,
#  'sharp': 5.41584043886187,
#  'she': 2.3319432147202814,
#  'news': 1.939683529381717,
#  'market': 1.6206392569018933,
#  'create': 3.4274046159092135,
#  'preannounce': 14.496086941312974,
#  'shielded': 9.631016521399083,
#  'frivolous': 9.098870719121376,
#  'protective': 7.754619954911829,
#  'issues': 3.3420826115665814,
#  'fair': 4.501531460473549,
#  'governing': 7.151157021063997,
#  'offspring': 9.1285161808699,
#  'morgan': 4.554829686633597,
#  'key': 3.3020336689777707,
#  'maintenance': 5.726485198664487,
#  'unit': 3.0212221676979913,
#  'appealed': 6.945889858752496,
#  'past': 2.6188028077897796,
#  'require': 4.298870248202922,
#  'owner': 4.058929365769553,
#  'baldwin': 9.378629359764798,
#  'm': 2.043551513474757,
#  'remaining': 4.49628822419309,
#  'access': 3.4857586546845507,
#  'geeks': 9.426924916805579,
#  'already': 2.3144022264081885,
#  'cases': 3.7161331350370337,
#  'source': 3.4821661356066174,
#  'relationship': 4.386815941159343,
#  'resource': 7.008821114478952,
#  'but': 0.4038607169878046,
#  'contributed': 4.273292038444864,
#  'awarded': 5.6226428287975985,
#  'corporate': 2.6921864746712405,
#  'yesterday': 1.9416351302472556,
#  'hit': 3.364321828231884,
#  'hole': 6.334055342028296,
#  'similar': 3.1711027991513214,
#  'how': 1.6640446238885798,
#  'kind': 3.241817529308003,
#  'injury': 5.785772475236767,
#  'medical': 4.165970360018619,
#  'country': 3.0764276697214457,
#  'technological': 6.411658160152268,
#  'options': 3.914213868329885,
#  'almirol': 17.30344186337058,
#  'offered': 3.432884489044164,
#  'cut': 2.868943942832429,
#  'paradox': 10.018039644508331,
#  'thus': 5.193284844416513,
#  'legislators': 7.242745931683024,
#  'balked': 7.714727227788314,
#  'sympathetic': 7.959145955454762,
#  'tom': 4.146568745421011,
#  'unfettered': 9.54855436120711,
#  'through': 1.6937436822862566,
#  'finding': 4.642331834626917,
#  'later': 2.677105401880531,
#  'tragedies': 10.360927358031338,
#  'broad': 4.894581427345819,
#  'tracy': 8.221292822016707,
#  'coverage': 4.805340619375727,
#  'labels': 6.290817324505519,
#  'passing': 5.581061228206777,
#  'little': 2.42184988836392,
#  'physician': 7.289421393055644,
#  'illness': 7.36533253715134,
#  'wilson': 6.177382747299898,
#  'energy': 3.52023897330619,
#  'ever': 3.131170634315878,
#  'name': 3.0288453129938544,
#  'healthnet': 13.603002145229487,
#  'announcer': 8.51227897481556,
#  'beautiful': 6.583197605083013,
#  'filed': 3.1626919605656494,
#  'now': 1.2672467823006257,
#  'recovering': 7.100093860390816,
#  'brian': 4.922169307658791,
#  'mad': 7.1524253244783305,
#  'w': 3.553677165024696,
#  'caused': 4.381600926296088,
#  'closing': 4.0392925236472506,
#  'two': 0.9056502635034414,
#  'deserves': 7.241395725650088,
#  'gallegos': 11.603002145229487,
#  'controversy': 5.648805834842612,
#  'justify': 6.561974876969432,
#  'offering': 3.527934459570537,
#  'copies': 5.787249385491212,
#  'sets': 5.537327105783856,
#  'gain': 3.8706390070187093,
#  'receive': 3.862053834023892,
#  'own': 2.09513128689194,
#  'entitled': 6.597809476009165,
#  'rise': 4.243928399436854,
#  'earlier': 2.380857460656915,
#  'approve': 5.3290272735650515,
#  'travelers': 6.067427671470495,
#  'works': 3.820633906643911,
#  'matter': 3.509432218349607,
#  'gq': 11.718479362649424,
#  'red': 4.308204692921521,
#  'michael': 3.0805715077140357,
#  'juror': 8.52536473383522,
#  'take': 1.8073683007227088,
#  'sells': 4.471343017331445,
#  'hartford': 7.343439931302498,
#  'hearings': 5.825177831788859,
#  'until': 2.3353151020143126,
#  'political': 4.391862621968431,
#  'quarters': 4.88532572216309,
#  'trickiest': 12.303441863370578,
#  'also': 0.7401562002285759,
#  'patients': 5.019774695879078,
#  'stakes': 5.6086487083706285,
#  'compared': 3.3126287842169697,
#  'argued': 4.72955803271411,
#  'hilfiger': 9.963591860485954,
#  'did': 1.7463671291734943,
#  'outcome': 5.521672351507448,
#  'groundwork': 9.01342301643796,
#  'house': 3.3495182655721885,
#  'divisions': 5.522492064620914,
#  'lewinsky': 9.57552140880738,
#  'nurse': 7.9747669360426325,
#  'local': 3.0195577003096097,
#  'walter': 6.106839736847409,
#  'manager': 3.2664955854192326,
#  'appeals': 5.1906765814852625,
#  'vhs': 10.0650371240455,
#  'maria': 7.748853011692941,
#  'best': 2.4099507162856653,
#  'resulting': 5.889813934346406,
#  'insurer': 6.347065706120908,
#  'why': 3.0176784379665755,
#  'plan': 2.640551004231517,
#  'london': 5.342353973373248,
#  'cents': 2.492820024358173,
#  'wide': 4.167091521916423,
#  'america': 2.7619217000789003,
#  'his': 1.2000106122988234,
#  '10th': 7.014575789204759,
#  'accountable': 7.208044840578022,
#  'weeks': 2.8949130890040737,
#  'motive': 8.17673739052739,
#  'recover': 5.876652968775017,
#  'stemmed': 7.748853011692941,
#  'addition': 3.3989953988648587,
#  'mcneil': 10.87717710866848,
#  'buy': 2.3167554002466297,
#  'memorial': 6.728848336032968,
#  'policies': 5.320091935694122,
#  'apply': 5.623082339856866,
#  'predicted': 4.775231966747869,
#  'notes': 5.115780497631458,
#  'turned': 3.5150293916135773,
#  'around': 2.3695668266632355,
#  'malone': 7.35946194902684,
#  'again': 3.1096855176721965,
#  'requiring': 5.689192135681178,
#  'profit': 2.76053091740144,
#  'unusual': 4.709350573110166,
#  'agreed': 2.6479111402149362,
#  'wont': 3.365884131515119,
#  'mark': 3.48555883542649,
#  'ran': 4.351428698481093,
#  'accounts': 4.481667881400011,
#  'remembers': 7.300626847763525,
#  'matters': 5.193611209091785,
#  'assembly': 5.758477430581341,
#  'manufacture': 7.127268714263089,
#  'saatchi': 9.990558908086223,
#  'month': 1.9777147936344133,
#  'three': 1.454990077095552,
#  'baby': 5.2306393288263715,
#  'award': 5.422710428228915,
#  'awards': 6.051959452750367,
#  'truly': 5.797630309450985,
#  'rushed': 6.604737196600234,
#  'benefits': 4.0147199505879305,
#  'advertise': 7.484859685889721,
#  'far': 2.434667527818529,
#  'november': 4.042375363371185,
#  'area': 2.9613671953714404,
#  'because': 1.080892209321689,
#  'shows': 3.779512419718909,
#  'becoming': 4.623521984852159,
#  'shortening': 10.457951812426204,
#  'billion': 1.4958605316353955,
#  'rose': 2.9044310304185883,
#  'waves': 7.4439070769879265,
#  'sick': 6.679560373357121,
#  'caption': 2.478731679092501,
#  'chairs': 6.752695077987336,
#  'special': 3.4957850696381043,
#  'closely': 4.585123052891317,
#  'connecticut': 5.85894457626677,
#  'reporting': 4.890342878455316,
#  'corporations': 5.043698599679797,
#  'dollars': 3.5001179443290886,
#  'complain': 6.516355538818962,
#  'specify': 7.1587836205386965,
#  'pushing': 5.167412013985027,
#  'stirred': 8.599538289925915,
#  'church': 6.097648613973422,
#  'strong': 2.952916991416108,
#  'cathy': 8.768166486749776,
#  'attrition': 7.481667881400011,
#  'described': 4.390178432741817,
#  'division': 2.620502127714484,
#  'economic': 3.8873040947922917,
#  'restrictions': 5.830243479693051,
#  'faulted': 8.945889858752494,
#  'dennison': 10.945889858752494,
#  'value': 2.9229131566264894,
#  'costs': 2.6906309460536386,
#  'battles': 6.582342674663393,
#  'gives': 4.197860682093142,
#  'complete': 3.9412240474574993,
#  'coveted': 7.402575055389831,
#  'moved': 3.8539062808757816,
#  'done': 2.9744865015892477,
#  'too': 2.242872578309177,
#  'noted': 3.823156542434207,
#  'fight': 4.315467339074426,
#  'merge': 5.718009811777616,
#  'impact': 3.9885754323174027,
#  'data': 3.2587062373136697,
#  'represented': 5.175125260467034,
#  'field': 3.6862039986244746,
#  'expected': 1.9890002333336403,
#  'wednesday': 3.020932557129742,
#  '1998when': 9.659585673595853,
#  'good': 1.9547482833421483,
#  'analyst': 2.2546570130324883,
#  'step': 3.665911311845269,
#  'foreman': 8.915424578025444,
#  'assembled': 6.879275574552479,
#  'worldwide': 3.910587823497706,
#  'end': 1.969378124899684,
#  'part': 1.7748961829593428,
#  'wrote': 3.79849876760046,
#  'hold': 3.6302432249077925,
#  'conversion': 7.268642900793312,
#  'settled': 5.053143445464246,
#  'estimates': 4.070721155405707,
#  'robert': 3.331449333273001,
#  'immediate': 5.209034230289371,
#  'latitude': 8.963591860485955,
#  'banging': 9.937119649124764,
#  'focus': 3.5053751430075155,
#  'sum': 6.415459730312125,
#  'sale': 3.1902694660267126,
#  'aug': 3.671469088835711,
#  'fear': 5.017172900690798,
#  'malice': 10.470551849205837,
#  'higher': 2.945271457801536,
#  'final': 3.498705811756549,
#  'components': 5.75221425977229,
#  'sure': 3.3240166680391052,
#  'inexperienced': 9.169015543149653,
#  'takes': 3.9858879266844145,
#  'began': 2.7590207162367504,
#  'wayne': 6.151791033397158,
#  '2000correction': 11.68873201925537,
#  'captures': 9.200154054958556,
#  'cassettes': 11.018039644508331,
#  'marketer': 7.4131775863494695,
#  'off': 1.6190493591089965,
#  'hazzard': 12.91112444059182,
#  'census': 8.911124440591818,
#  'circle': 6.835836313287581,
#  'correction': 6.401066748884553,
#  'domestic': 5.022961053052205,
#  'consumption': 7.121047509966051,
#  'parentheses': 8.729794675877256,
#  'jurors': 6.429997750855202,
#  'than': 0.6877547588153522,
#  'medicine': 6.047233174843192,
#  'interest': 2.9106548897200124,
#  'person': 3.8339272286621884,
#  'published': 4.927045112287738,
#  'trading': 3.150285708799349,
#  'decades': 4.499916126459152,
#  'constitution': 8.384578626095983,
#  'services': 2.3784902176476153,
#  'define': 7.3147571765984125,
#  'practicing': 8.146094928007736,
#  'refiner': 9.860498367521851,
#  'prevent': 4.755583357312162,
#  'largely': 4.202122708947302,
#  'let': 3.330013547830478,
#  'meanwhile': 3.9949606187265574,
#  'realize': 5.522492064620914,
#  'him': 2.3977258139808795,
#  'identified': 5.104689898176843,
#  'information': 2.408292636525074,
#  'drilling': 6.978136408280896,
#  'qtr': 6.723183295870791,
#  'focused': 4.250704013820759,
#  'keeping': 4.599754537403032,
#  'sacramento': 6.78675691406097,
#  'legally': 6.6372178605674,
#  'pcs': 5.510245004309635,
#  'international': 2.7634349426192926,
#  'enough': 2.7231832958707907,
#  'equipment': 3.7563063315397147,
#  'fails': 6.969168578063388,
#  'operates': 4.648805834842611,
#  'sister': 6.185149630343589,
#  'systems': 3.055885155964167,
#  'highest': 4.516559669705881,
#  'made': 1.540618653353153,
#  'human': 4.571062416979222,
#  'work': 1.9625486215650239,
#  'meaning': 5.5619748769694315,
#  'see': 2.13555335018993,
#  'pioneered': 7.632785614252139,
#  'performance': 3.348518571340258,
#  'total': 3.178109118905856,
#  'graffiti': 9.40257505538983,
#  'reported': 2.75660767776345,
#  'frontier': 6.717540413679807,
#  'magazine': 4.69518704139267,
#  'undisclosed': 6.324016668039105,
#  'added': 2.6263278756054538,
#  'gas': 3.9826413144889417,
#  'integration': 6.34126883226087,
#  'handled': 5.712854813455544,
#  'brokers': 6.399560017634399,
#  'merger': 3.4373220700675087,
#  'tried': 3.6821912550329126,
#  'results': 3.1250882398576856,
#  'period': 3.1303113059867065,
#  'uses': 4.493673734660165,
#  'written': 4.428844670968945,
#  'yet': 2.712796339647009,
#  'aiming': 7.543553680148744,
#  'quarterly': 4.592850644863822,
#  'iri': 11.445460868243007,
#  'career': 4.271568388250719,
#  'anne': 6.657783430961868,
#  'hoping': 4.809836556313458,
#  'paying': 3.920952926925532,
#  'previous': 3.7274299891637988,
#  'processing': 5.660938834590058,
#  'april': 3.4325955551587115,
#  'hospital': 5.136337380990645,
#  'call': 2.5635557972878615,
#  'ink': 7.2106847224507264,
#  'jot': 11.945889858752496,
#  'comes': 3.113694505563002,
#  'share': 1.794409177064078,
#  'deal': 2.0015527532603885,
#  'nearly': 2.576478702709721,
#  'used': 2.204094052967386,
#  'deceased': 9.502541963450275,
#  'plain': 6.7354857879551115,
#  'original': 4.27036305723996,
#  'any': 1.5461560385167774,
#  'potential': 3.0881363881422916,
#  'mexico': 5.271740660630277,
#  'contribute': 6.176737390527388,
#  'low': 2.903029351071767,
#  'asked': 2.7482536120246372,
#  'plans': 2.300582906697782,
#  'precluded': 10.281074050342125,
#  'signal': 5.695649221451369,
#  'main': 4.03680170743973,
#  'meetings': 4.998805339563308,
#  'fees': 4.306262382432957,
#  'method': 6.431536625711392,
#  'models': 4.770112131064745,
#  'sense': 3.763071619627012,
#  'urged': 5.66681724282693,
#  'per': 2.8855893484846806,
#  'resources': 4.282809101712872,
#  'revenues': 4.1371218381035995,
#  'ms': 4.362944728912374,
#  'heard': 4.328668795481237,
#  'significantly': 4.922169307658791,
#  'cheniere': 13.133516861928266,
#  'saying': 2.8944487840284,
#  'wanted': 3.2365117945064816,
#  'diluted': 5.4872581819382376,
#  'polled': 7.077029670581793,
#  'lost': 2.7359016443802453,
#  'neighboring': 7.8297361137511645,
#  'nonprofit': 5.93766622804431,
#  'includes': 3.4310555509658993,
#  'chief': 1.4409740053174593,
#  'damage': 5.049594378383175,
#  'washington': 2.3503821956853685,
#  'shelves': 6.401066748884553,
#  'abdominal': 9.999661115193476,
#  'simon': 6.741199439149506,
#  'incorrect': 7.710984826102498,
#  'backlash': 8.081854742105774,
#  'respiratory': 8.393548779600538,
#  'referred': 5.881377097197767,
#  'judges': 6.612570854078266,
#  'believing': 7.696111549620968,
#  'suing': 6.334775070175371,
#  'capital': 3.5150293916135773,
#  'shock': 6.354344707641371,
#  'boosted': 6.2590477440121255,
#  'cash': 2.8812456623103353,
#  'sign': 3.981232019621684,
#  'theo': 10.259047744012125,
#  'acquisition': 3.4997143368174646,
#  'brother': 5.693339800370914,
#  'telling': 5.015729483821129,
#  'financial': 1.947643435647379,
#  'june': 3.2223745833092967,
#  'unpaid': 8.0413470180004,
#  'payment': 4.9871603316243585,
#  'medium': 6.154965281192301,
#  'east': 4.2655517782280725,
#  'told': 2.5414232435327277,
#  'under': 1.8058394765870902,
#  'sold': 2.8067128919898727,
#  'photograph': 3.5953279298758476,
#  'disloyal': 12.133516861928266,
#  'times': 0.8508306000670435,
#  'segments': 6.611698344199304,
#  'emotional': 6.275535866800695,
#  'third': 2.4502785344691382,
#  'hand': 3.6716963922930725,
#  'except': 4.756788515715623,
#  'corp': 2.123416180946258,
#  'portability': 10.113617304490562,
#  'rather': 3.200318006892467,
#  'returned': 4.685056361111972,
#  'agents': 5.447794697343313,
#  'el': 5.718949066394704,
#  'skills': 5.7936668590436415,
#  'rushes': 9.819626086106323,
#  'v': 5.1360237175388415,
#  'schools': 5.296765148061591,
#  'accepted': 5.0653357259385015,
#  'concentrating': 8.001945668388029,
#  'arrive': 6.445460868243006,
#  'next': 1.7801555844525483,
#  'come': 2.276097369600518,
#  'figures': 4.51329703642078,
#  'american': 2.5262893078952766,
#  'expects': 3.704110120414286,
#  'license': 5.516763829479927,
#  'growing': 3.250958719434053,
#  'closed': 3.1303113059867065,
#  'ad': 4.806338506353701,
#  'competition': 3.1803712832907727,
#  'investment': 2.817926983770215,
#  'multiline': 14.303441863370578,
#  'increased': 3.534017221817825,
#  ...}

# %% [markdown]
# ## Functions!

# %%
def calculateCosine1(W1,W2):
    #resultww = []
    result = 1 - spatial.distance.cosine(Embeddings1[W1], Embeddings1[W2])
    #if W1.lower() in weightdict:
        
    result = round(result, 2)
    return(result)

# %%
def calculateSentenceSim1(S1,S2):
    pairs = []
    for index1,word1 in enumerate(S1):
        for index2,word2 in enumerate(S2):
            pairs.append([index1+1, word1,index2+1,word2,calculateCosine1(word1,word2)*weightdict[word1]*weightdict[word2]])
    pairs = sorted(pairs, key=lambda x:x[4], reverse=True)
    
    # Now create the similarity vector
    tempPairsVector = []
    for index, row in enumerate(pairs):


        foundOne=False
        for tempRow in tempPairsVector:

            if tempRow[0] == row[0] or tempRow[2] == row[2]:
                foundOne=True
        if foundOne==False:
            tempPairsVector.append(row)

#Now create the vector of the up to 20 highest cosines
    sentenceSimVector = [] #[None] * 20
    for index,row in enumerate(tempPairsVector):
        sentenceSimVector.append(row[4])
    
#Pad the similarity vector with nulls    
    length = 20 - len(sentenceSimVector)
    for x in range(0, length):
        sentenceSimVector.append(None)            
    return(sentenceSimVector)

# %% [markdown]
# ## Now with all the data

# %%
df_test = df.head(5)
# Out:
# DocumentID    161754
# Frequency     161754
# dtype: int64

# %% [markdown]
# ## Set up the data

# %% [markdown]
# ## Make a dictionary from the DataFrame

# %%
df_test = ItemsDF.head(20)

# %%
import re
new = {}
dictionary = {x[0]: { x[1] : x[2:] } for x in ItemsDF.itertuples(index=False)}
for key, item in dictionary.items():
    #print(key, item)
    for key2, item2 in item.items():
        itemslist = (list(item2))  
        words = ([word for sentence in itemslist for word in tokenizer.tokenize(sentence)])
        for word in words:
            if word not in Embeddings1.keys():
                words.remove(word)
        #lowering is something we should think about
        filtered_sentence = [w for w in words if not w in stop_words]
        #filtered_sentence = [w.lower() for w in words if not w in stop_words]
        #print(key, key2)
        new[key] =  [key2, filtered_sentence]
new
# Out:
# {1: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'understanding',
#    'module',
#    'integrates',
#    'modules',
#    'systems']],
#  2: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'ability',
#    'ask',
#    'penetrating',
#    'questions',
#    'module']],
#  3: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'improved',
#    'knowledge',
#    'module']],
#  4: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'knowledge',
#    'module',
#    'training',
#    'documents',
#    'end',
#    'users']],
#  5: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'knowledge',
#    'setting',
#    'configuration',
#    'tables',
#    'support',
#    'client',
#    'business',
#    'processes']],
#  6: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'improved',
#    'ability',
#    'develop',
#    'test',
#    'scripts',
#    'module']],
#  8: [15,
#   ['Client',
#    'Alisha',
#    'vision',
#    'implementation',
#    'Purchasing',
#    'module',
#    'project',
#    'trying',
#    'achieve']],
#  10: [15,
#   ['Client',
#    'Alisha',
#    'clear',
#    'understanding',
#    'goals',
#    'tasks',
#    'responsibilities',
#    'implementing',
#    'Purchasing',
#    'module']],
#  11: [15,
#   ['Client',
#    'Alisha',
#    'technical',
#    'competence',
#    'absorb',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  12: [15,
#   ['Client',
#    'Alisha',
#    'managerial',
#    'competence',
#    'absorb',
#    'business',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  26: [17,
#   ['Communication', 'Consultant', 'William', 'Very', 'easy', 'demanding']],
#  27: [17, ['Communication', 'Client', 'Alisha', 'Very', 'easy', 'demanding']],
#  28: [17,
#   ['Collaboration',
#    'Consultant',
#    'William',
#    'Is',
#    'sought',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Is',
#    'often',
#    'avoided',
#    'Occurs',
#    'I',
#    'alternative']],
#  29: [17,
#   ['Collaboration',
#    'Client',
#    'Alisha',
#    '2',
#    'Is',
#    'sought',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Is',
#    'often',
#    'avoided',
#    'Occurs',
#    'I',
#    'alternative']],
#  30: [17,
#   ['Collaboration',
#    'Consultant',
#    'William',
#    'Is',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'usually',
#    'avoided',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Occurs',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'alternative']],
#  31: [17,
#   ['Collaboration',
#    'Client',
#    'Alisha',
#    'Is',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'usually',
#    'avoided',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Occurs',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'alternative']],
#  32: [18,
#   ['I',
#    'enjoy',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  33: [18,
#   ['The',
#    'difficult',
#    'understand',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    'I',
#    'enjoy',
#    'learning',
#    '1']],
#  34: [18,
#   ['I',
#    'enjoy',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    'completely',
#    'new']],
#  35: [18,
#   ['I',
#    'feel',
#    'I',
#    'personally',
#    'benefitting',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    '1',
#    '2']],
#  36: [18,
#   ['I',
#    'want',
#    'find',
#    'good',
#    'I',
#    'really',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  37: [18,
#   ['I',
#    'comfortable',
#    'I',
#    'set',
#    'goals',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    '2']],
#  38: [19,
#   ['I',
#    'keenly',
#    'aware',
#    'income',
#    'goals',
#    'I',
#    'I',
#    'learn',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    '2']],
#  39: [19,
#   ['I',
#    'strongly',
#    'motivated',
#    'money',
#    'I',
#    'earn',
#    'I',
#    'learn',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    '1',
#    '2']],
#  40: [19,
#   ['I',
#    'keenly',
#    'aware',
#    'promotion',
#    'goals',
#    'I',
#    'I',
#    'learn',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    '2']],
#  41: [19,
#   ['If',
#    'I',
#    'learn',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    'I',
#    'want',
#    'people',
#    'find',
#    'good',
#    'I',
#    '1']],
#  42: [19,
#   ['I',
#    'strongly',
#    'motivated',
#    'recognition',
#    'I',
#    'earn',
#    'people',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    '1']],
#  43: [19,
#   ['I',
#    'feel',
#    'I',
#    'earning',
#    'something',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  44: [20, ['Consultant', 'William', 'good', 'command', 'language']],
#  45: [20, ['Consultant', 'William', 'typically', 'gets', 'right', 'point']],
#  46: [20, ['Consultant', 'William', 'deal', 'others', 'effectively']],
#  47: [20,
#   ['Consultant',
#    'William',
#    'written',
#    'communication',
#    'difficult',
#    'understand',
#    'Reverse',
#    'coded']],
#  48: [20, ['Consultant', 'William', 'expresses', 'ideas', 'clearly']],
#  49: [20,
#   ['Consultant',
#    'William',
#    'oral',
#    'communication',
#    'difficult',
#    'understand',
#    'Reverse',
#    'coded']],
#  50: [20,
#   ['Consultant',
#    'William',
#    'usually',
#    'says',
#    'right',
#    'thing',
#    'right',
#    'time']],
#  51: [21, ['Client', 'Alisha', 'sensitive', 'others', 'needs']],
#  52: [21, ['Client', 'Alisha', 'pays', 'attention', 'people', 'say']],
#  53: [21, ['Client', 'Alisha', 'good', 'listener']],
#  54: [21, ['Client', 'Alisha', 'easy', 'talk']],
#  55: [21,
#   ['Client',
#    'Alisha',
#    'usually',
#    'responds',
#    'messages',
#    'memos',
#    'phone',
#    'calls',
#    'reports',
#    'etc',
#    'quickly']],
#  56: [22, ['Consultant', 'William', 'trustworthy']],
#  58: [22, ['Consultant', 'William', 'experienced']],
#  60: [22, ['Consultant', 'William', 'well', 'trained']],
#  96: [34,
#   ['I', 'earn', 'respect', 'others', 'participating', 'Message', 'Boards']],
#  97: [34, ['I', 'feel', 'participation', 'improves', 'status', 'profession']],
#  98: [34,
#   ['I',
#    'participate',
#    'Message',
#    'Boards',
#    'improve',
#    'reputation',
#    'profession']],
#  104: [38,
#   ['I', 'would', 'feel', 'loss', 'Message', 'Boards', 'longer', 'available']],
#  105: [38, ['I', 'really', 'care', 'fate', 'Message', 'Boards']],
#  106: [38, ['I', 'feel', 'great', 'deal', 'loyalty', 'Message', 'Boards']],
#  111: [42,
#   ['Data',
#    'shared',
#    'easily',
#    'among',
#    'various',
#    'internal',
#    'systems',
#    'e',
#    'g',
#    'forecasting',
#    'production',
#    'manufacturing',
#    'shipment',
#    'finance',
#    'accounting',
#    'etc']],
#  112: [42,
#   ['Order',
#    'changes',
#    'automatically',
#    'reflected',
#    'downstream',
#    'processes',
#    'systems',
#    'e',
#    'g',
#    'inventory',
#    'manufacturing',
#    'resource',
#    'planning',
#    'manufacturing',
#    'systems']],
#  113: [42,
#   ['Our',
#    'systems',
#    'easily',
#    'transmit',
#    'integrate',
#    'process',
#    'data',
#    'suppliers',
#    'vendors',
#    'customers']],
#  114: [42,
#   ['Our',
#    'systems',
#    'allow',
#    'continuous',
#    'monitoring',
#    'order',
#    'status',
#    'various',
#    'stages',
#    'process',
#    'e',
#    'g',
#    'manufacturing',
#    'shipping']],
#  115: [42,
#   ['Employees',
#    'easily',
#    'retrieve',
#    'information',
#    'various',
#    'databases',
#    'decision',
#    'support',
#    'e',
#    'g',
#    'cost',
#    'information',
#    'reporting',
#    'tools']],
#  116: [43,
#   ['All',
#    'product',
#    'related',
#    'information',
#    'available',
#    'online',
#    'e',
#    'g',
#    'catalog',
#    'product',
#    'description',
#    'detailed',
#    'specifications',
#    'price',
#    'discount',
#    'etc']],
#  117: [43,
#   ['Customers',
#    'customize',
#    'orders',
#    'online',
#    'without',
#    'phone',
#    'fax',
#    'face',
#    'face',
#    'interactions']],
#  118: [43,
#   ['A',
#    'comprehensive',
#    'Frequently',
#    'Asked',
#    'Questions',
#    'section',
#    'company',
#    'oar',
#    'products',
#    'services',
#    'contact',
#    'information',
#    'etc',
#    'available',
#    'online']],
#  119: [43,
#   ['Customers',
#    'conveniently',
#    'contact',
#    'service',
#    'representatives',
#    'seek',
#    'service',
#    'online']],
#  120: [43,
#   ['Customers',
#    'see',
#    'personalized',
#    'content',
#    'e',
#    'g',
#    'products',
#    'prices',
#    'order',
#    'history',
#    'order',
#    'status',
#    'etc',
#    'log',
#    'onto',
#    'web',
#    'site']],
#  121: [44,
#   ['Customer',
#    'feedback',
#    'field',
#    'incidence',
#    'reports',
#    'e',
#    'g',
#    'product',
#    'failures',
#    'defects',
#    'shared',
#    'suppliers',
#    'vendors',
#    'real',
#    'time']],
#  122: [44,
#   ['Process',
#    'quality',
#    'information',
#    'e',
#    'g',
#    'line',
#    'rejection',
#    'rates',
#    'yields',
#    'shared',
#    'electronically',
#    'relevant',
#    'trading',
#    'partners',
#    'real',
#    'time']],
#  123: [44,
#   ['Changes',
#    'e',
#    'g',
#    'order',
#    'changes',
#    'product',
#    'design',
#    'changes',
#    'etc',
#    'communicated',
#    'trading',
#    'partners',
#    'electronically',
#    'real',
#    'time']],
#  124: [45,
#   ['Continuously',
#    'updated',
#    'inventory',
#    'information',
#    'shared',
#    'trading',
#    'partners',
#    'online']],
#  125: [45,
#   ['Continuously',
#    'updated',
#    'production',
#    'schedules',
#    'capacity',
#    'e',
#    'g',
#    'machine',
#    'downtime',
#    'manpower',
#    'availability',
#    'information',
#    'shared',
#    'online',
#    'trading',
#    'partners']],
#  126: [45,
#   ['Continuously',
#    'updated',
#    'product',
#    'demand',
#    'information',
#    'e',
#    'g',
#    'actual',
#    'forecasted',
#    'shared',
#    'online']],
#  127: [46,
#   ['We',
#    'provide',
#    'online',
#    'communities',
#    'e',
#    'g',
#    'discussion',
#    'forms',
#    'online',
#    'chat',
#    'rooms',
#    'suppliers',
#    'vendors']],
#  128: [46,
#   ['We',
#    'make',
#    'available',
#    'comprehensive',
#    'online',
#    'Frequently',
#    'Asked',
#    'Questions',
#    'section',
#    'e',
#    'g',
#    'contact',
#    'information',
#    'glossary',
#    'events',
#    'etc',
#    'trading',
#    'partners',
#    'online']],
#  129: [46,
#   ['We',
#    'make',
#    'frequently',
#    'updated',
#    'supplier',
#    'vendor',
#    'evaluation',
#    'reports',
#    'available',
#    'online']],
#  130: [47,
#   ['The',
#    'method',
#    'sharing',
#    'product',
#    'roadmap',
#    'demand',
#    'forecast',
#    'suppliers',
#    'well',
#    'defined']],
#  131: [47,
#   ['Information',
#    'exchange',
#    'policies',
#    'suppliers',
#    'e',
#    'frequency',
#    'precision',
#    'real',
#    'time',
#    'delayed',
#    'format',
#    'channel',
#    'well',
#    'defined']],
#  132: [47,
#   ['The',
#    'standard',
#    'operating',
#    'procedures',
#    'cover',
#    'procurement',
#    'scenarios',
#    'e',
#    'g',
#    'well',
#    'defined',
#    'rules',
#    'large',
#    'versus',
#    'small',
#    'procurement']],
#  133: [47,
#   ['Supplier', 'vendor', 'selection', 'criteria', 'well', 'documented']],
#  134: [47, ['Supplier', 'vendor', 'evaluation', 'metrics', 'well', 'defined']],
#  135: [47,
#   ['The',
#    'vendor',
#    'supplier',
#    'quality',
#    'monitoring',
#    'process',
#    'well',
#    'defined']],
#  136: [48,
#   ['Customers', 'generally', 'one', 'contact', 'point', 'service', 'needs']],
#  137: [48,
#   ['There',
#    'small',
#    'number',
#    'steps',
#    'resolving',
#    'customer',
#    'complaints']],
#  138: [48,
#   ['Customer',
#    'feedback',
#    'quickly',
#    'disseminated',
#    'organizational',
#    'processes']],
#  139: [49,
#   ['Our',
#    'customers',
#    'feel',
#    'comfortable',
#    'regarding',
#    'security',
#    'privacy',
#    'electronic',
#    'commerce',
#    'company']],
#  140: [49,
#   ['Our',
#    'customers',
#    'consider',
#    'important',
#    'engage',
#    'electronic',
#    'commerce']],
#  141: [50,
#   ['Our',
#    'suppliers',
#    'vendors',
#    'Internet',
#    'based',
#    'systems',
#    'engage',
#    'electronic',
#    'business']],
#  142: [50,
#   ['Our',
#    'suppliers',
#    'vendors',
#    'feel',
#    'comfortable',
#    'regarding',
#    'security',
#    'privacy',
#    'etc',
#    'engaging',
#    'electronic',
#    'business']],
#  143: [50,
#   ['Our',
#    'suppliers',
#    'vendors',
#    'willing',
#    'share',
#    'information',
#    'electronically',
#    'us']],
#  144: [50,
#   ['Our',
#    'suppliers',
#    'vendors',
#    'consider',
#    'important',
#    'engage',
#    'electronic',
#    'business']],
#  145: [50,
#   ['Our',
#    'suppliers',
#    'vendors',
#    'consider',
#    'important',
#    'improve',
#    'coordination',
#    'collaboration',
#    'us']],
#  152: [61,
#   ['Mental',
#    'Demand',
#    'much',
#    'mental',
#    'perceptual',
#    'activity',
#    'required',
#    'e',
#    'g',
#    'thinking',
#    'deciding',
#    'calculating',
#    'remembering',
#    'looking',
#    'searching',
#    'etc',
#    'Was',
#    'task',
#    'easy',
#    'demanding',
#    'simple',
#    'complex',
#    'exacting',
#    'forgiving']],
#  153: [61,
#   ['Physical',
#    'Demand',
#    'much',
#    'physical',
#    'activity',
#    'required',
#    'e',
#    'g',
#    'pushing',
#    'pulling',
#    'turning',
#    'controlling',
#    'activating',
#    'etc',
#    'Was',
#    'task',
#    'easy',
#    'demanding',
#    'slow',
#    'brisk',
#    'slack',
#    'strenuous',
#    'restful',
#    'laborious']],
#  154: [61,
#   ['Time',
#    'Demand',
#    'much',
#    'time',
#    'pressure',
#    'feel',
#    'due',
#    'rate',
#    'pace',
#    'tasks',
#    'occurred',
#    'Was',
#    'pace',
#    'slow',
#    'leisurely',
#    'rapid',
#    'frantic']],
#  155: [61,
#   ['Performance',
#    'successful',
#    'think',
#    'accomplishing',
#    'goals',
#    'task',
#    'How',
#    'satisfied',
#    'performance',
#    'accomplishing',
#    'goals']],
#  156: [61,
#   ['Effort',
#    'hard',
#    'work',
#    'mentally',
#    'physically',
#    'accomplish',
#    'level',
#    'performance']],
#  157: [61,
#   ['Frustration',
#    'Level',
#    'insecure',
#    'discouraged',
#    'irritated',
#    'stressed',
#    'annoyed',
#    'versus',
#    'secure',
#    'gratified',
#    'content',
#    'relaxed',
#    'complacent',
#    'feel',
#    'task']],
#  158: [72, ['Overall', 'management', 'encouraged', 'use', 'DW']],
#  159: [72, ['User', 'satisfaction', 'major', 'concern', 'management']],
#  160: [73, ['A', 'high', 'level', 'champion', 'DW', 'came', 'IS']],
#  161: [73,
#   ['A', 'high', 'level', 'champion', 'DW', 'came', 'functional', 'area']],
#  162: [74,
#   ['Using',
#    'system',
#    'job',
#    'would',
#    'enable',
#    'accomplish',
#    'tasks',
#    'quickly']],
#  163: [74, ['Using', 'system', 'would', 'improve', 'job', 'performance']],
#  164: [74, ['Using', 'system', 'job', 'would', 'increase', 'productivity']],
#  165: [74, ['Using', 'system', 'would', 'enhance', 'effectiveness', 'job']],
#  166: [74, ['Using', 'system', 'would', 'make', 'easier', 'job']],
#  167: [74, ['I', 'would', 'find', 'system', 'useful', 'job']],
#  168: [75, ['The', 'DW', 'project', 'adequately', 'funded']],
#  169: [75,
#   ['The',
#    'DW',
#    'project',
#    'enough',
#    'team',
#    'members',
#    'get',
#    'work',
#    'done']],
#  170: [75, ['The', 'DW', 'project', 'given', 'enough', 'time', 'completion']],
#  171: [76, ['IS', 'users', 'worked', 'together', 'team', 'DW', 'project']],
#  172: [76, ['Users', 'assigned', 'full', 'time', 'parts', 'DW', 'project']],
#  173: [76,
#   ['Users',
#    'performed',
#    'hands',
#    'activities',
#    'e',
#    'g',
#    'data',
#    'modeling',
#    'DW',
#    'project']],
#  174: [77,
#   ['Using',
#    'system',
#    'job',
#    'would',
#    'enable',
#    'accomplish',
#    'tasks',
#    'quickly']],
#  175: [77, ['Using', 'system', 'would', 'improve', 'job', 'performance']],
#  176: [77, ['Using', 'system', 'job', 'would', 'increase', 'productivity']],
#  177: [77, ['Using', 'system', 'would', 'enhance', 'effectiveness', 'job']],
#  178: [77, ['Using', 'system', 'would', 'make', 'easier', 'job']],
#  179: [77, ['I', 'would', 'find', 'system', 'useful', 'job']],
#  180: [78,
#   ['Members',
#    'DW',
#    'team',
#    'including',
#    'consultants',
#    'right',
#    'technical',
#    'skills',
#    'DW']],
#  181: [78, ['Members', 'DW', 'team', 'good', 'interpersonal', 'skills']],
#  182: [79, ['Use', 'system', 'effect', 'performance', 'job']],
#  183: [79,
#   ['Use', 'system', 'decrease', 'time', 'needed', 'important', 'job']],
#  184: [79,
#   ['Use', 'system', 'significantly', 'increase', 'quality', 'output', 'job']],
#  185: [79,
#   ['Use',
#    'system',
#    'increase',
#    'effectiveness',
#    'performing',
#    'job',
#    'tasks']],
#  186: [79, ['Use', 'increase', 'quantity', 'output', 'amount', 'effort']],
#  187: [79,
#   ['Considering',
#    'tasks',
#    'general',
#    'extent',
#    'use',
#    'system',
#    'could',
#    'assist',
#    'job']],
#  188: [80,
#   ['Common',
#    'definitions',
#    'key',
#    'data',
#    'items',
#    'implemented',
#    'across',
#    'source',
#    'systems']],
#  189: [80,
#   ['The',
#    'data',
#    'sources',
#    'used',
#    'DW',
#    'diverse',
#    'disparate',
#    'applications',
#    'systems']],
#  190: [80,
#   ['A',
#    'significant',
#    'number',
#    'source',
#    'systems',
#    'modified',
#    'provide',
#    'data',
#    'DW']],
#  191: [81,
#   ['The',
#    'DW',
#    'technology',
#    'project',
#    'team',
#    'used',
#    'worked',
#    'well',
#    'technology',
#    'already',
#    'place',
#    'organization']],
#  192: [81, ['Appropriate', 'technology', 'available', 'implement', 'DW']],
#  193: [82, ['Using', 'system', 'enables', 'accomplish', 'tasks', 'quickly']],
#  194: [82, ['Using', 'system', 'improves', 'quality', 'work', 'I', 'job']],
#  195: [82, ['Using', 'system', 'enhances', 'effectiveness', 'job']],
#  196: [82, ['Using', 'system', 'increases', 'productivity']],
#  197: [83,
#   ['Any',
#    'political',
#    'resistance',
#    'DW',
#    'organization',
#    'dealt',
#    'effectively']],
#  198: [83,
#   ['Change', 'organization', 'created', 'DW', 'managed', 'effectively']],
#  199: [83, ['The', 'DW', 'support', 'people', 'throughout', 'organization']],
#  200: [84,
#   ['The',
#    'DW',
#    'project',
#    'met',
#    'critical',
#    'project',
#    'deadlines',
#    'e',
#    'g',
#    'rollout',
#    'deadline',
#    'initial',
#    'development',
#    'deadline']],
#  201: [84, ['The', 'cost', 'DW', 'exceed', 'budgeted', 'amount']],
#  202: [84,
#   ['The',
#    'DW',
#    'project',
#    'provided',
#    'DW',
#    'functionality',
#    'supposed',
#    'provide']],
#  203: [85,
#   ['If', 'I', 'use', 'system', 'I', 'increase', 'effectiveness', 'job']],
#  204: [85, ['I', 'spend', 'less', 'time', 'routine', 'job', 'tasks']],
#  205: [85, ['I', 'increase', 'quality', 'output', 'job']],
#  206: [85, ['I', 'increase', 'quantity', 'output', 'amount', 'effort']],
#  207: [85, ['My', 'coworkers', 'perceive', 'competent']],
#  208: [85, ['I', 'increase', 'chances', 'obtaining', 'promotion']],
#  209: [85, ['I', 'increase', 'chances', 'getting', 'raise']],
#  210: [86, ['Many', 'technical', 'problems', 'arose', 'DW', 'implementation']],
#  211: [86,
#   ['Numerous', 'technical', 'constraints', 'imposed', 'DW', 'implementation']],
#  212: [87, ['Learning', 'operate', 'system', 'would', 'easy']],
#  213: [87, ['I', 'would', 'find', 'easy', 'get', 'system', 'I', 'want']],
#  214: [87,
#   ['My', 'interaction', 'system', 'would', 'clear', 'understandable']],
#  215: [87, ['I', 'would', 'find', 'system', 'flexible', 'interact']],
#  216: [87, ['It', 'would', 'easy', 'become', 'skillful', 'using', 'system']],
#  217: [87, ['I', 'would', 'find', 'system', 'easy', 'use']],
#  218: [88,
#   ['Users',
#    'applications',
#    'accurate',
#    'data',
#    'DW',
#    'source',
#    'systems',
#    'e',
#    'g',
#    'transaction',
#    'systems']],
#  219: [88,
#   ['DW',
#    'provides',
#    'comprehensive',
#    'data',
#    'users',
#    'applications',
#    'source',
#    'systems',
#    'provided']],
#  220: [88,
#   ['DW',
#    'provides',
#    'correct',
#    'data',
#    'users',
#    'applications',
#    'respect',
#    'source',
#    'systems']],
#  221: [88,
#   ['DW',
#    'improved',
#    'consistency',
#    'data',
#    'users',
#    'applications',
#    'source',
#    'systems']],
#  222: [89, ['Using', 'system', 'takes', 'much', 'time', 'normal', 'duties']],
#  223: [89,
#   ['Working', 'system', 'complicated', 'difficult', 'understand', 'going']],
#  224: [89,
#   ['Using',
#    'system',
#    'involves',
#    'much',
#    'time',
#    'mechanical',
#    'operations',
#    'e',
#    'g',
#    'data',
#    'input']],
#  225: [89,
#   ['It',
#    'takes',
#    'long',
#    'learn',
#    'use',
#    'system',
#    'make',
#    'worth',
#    'effort']],
#  226: [90, ['My', 'interaction', 'system', 'clear', 'understandable']],
#  227: [90, ['I', 'believe', 'easy', 'get', 'system', 'I', 'want']],
#  228: [90, ['Overall', 'I', 'believe', 'system', 'easy', 'use']],
#  229: [90, ['Learning', 'operate', 'system', 'easy']],
#  230: [91, ['DW', 'flexibly', 'adjust', 'new', 'demands', 'conditions']],
#  231: [91,
#   ['DW',
#    'effectively',
#    'integrates',
#    'data',
#    'systems',
#    'servicing',
#    'different',
#    'functional',
#    'areas']],
#  232: [91, ['DW', 'versatile', 'addressing', 'data', 'needs', 'arise']],
#  233: [91,
#   ['DW',
#    'effectively',
#    'integrates',
#    'data',
#    'variety',
#    'data',
#    'sources',
#    'within',
#    'organization']],
#  234: [92, ['DW', 'changed', 'job', 'significantly']],
#  235: [92,
#   ['DW',
#    'reduced',
#    'time',
#    'takes',
#    'support',
#    'decision',
#    'making',
#    'end',
#    'user',
#    'community']],
#  236: [92,
#   ['DW',
#    'reduced',
#    'effort',
#    'takes',
#    'support',
#    'decision',
#    'making',
#    'end',
#    'user',
#    'community']],
#  237: [93, ['People', 'influence', 'behavior', 'think', 'I', 'use', 'system']],
#  238: [93, ['People', 'important', 'think', 'I', 'use', 'system']],
#  239: [94, ['I', 'use', 'system', 'proportion', 'coworkers', 'use', 'system']],
#  240: [94,
#   ['The', 'senior', 'management', 'business', 'helpful', 'use', 'system']],
#  241: [94, ['My', 'supervisor', 'supportive', 'use', 'system', 'job']],
#  242: [94, ['In', 'general', 'organization', 'supported', 'use', 'system']],
#  243: [95, ['People', 'organization', 'use', 'system', 'prestige']],
#  244: [95, ['People', 'organization', 'use', 'system', 'high', 'profile']],
#  245: [95, ['Having', 'system', 'status', 'symbol', 'organization']],
#  246: [96, ['I', 'control', 'using', 'system']],
#  247: [96, ['I', 'resources', 'necessary', 'use', 'system']],
#  248: [96, ['I', 'knowledge', 'necessary', 'use', 'system']],
#  249: [96,
#   ['Given',
#    'resources',
#    'opportunities',
#    'knowledge',
#    'takes',
#    'use',
#    'system',
#    'would',
#    'easy',
#    'use',
#    'system']],
#  250: [96, ['The', 'system', 'compatible', 'systems', 'I', 'use']],
#  251: [97, ['Guidance', 'available', 'selection', 'system']],
#  252: [97,
#   ['Specialized', 'instruction', 'concerning', 'system', 'available']],
#  253: [97,
#   ['A',
#    'specific',
#    'person',
#    'group',
#    'available',
#    'assistance',
#    'system',
#    'difficulties']],
#  254: [98, ['Using', 'system', 'compatible', 'aspects', 'work']],
#  255: [98,
#   ['I',
#    'think',
#    'using',
#    'system',
#    'fits',
#    'well',
#    'way',
#    'I',
#    'like',
#    'work']],
#  256: [98, ['Using', 'system', 'fits', 'work', 'style']],
#  257: [99, ['Using', 'system', 'bad', 'good', 'idea']],
#  258: [99, ['Using', 'system', 'foolish', 'wise', 'idea']],
#  259: [99, ['I', 'dislike', 'like', 'idea', 'using', 'system']],
#  260: [99, ['Using', 'system', 'unpleasant', 'pleasant']],
#  261: [100, ['I', 'find', 'using', 'system', 'enjoyable']],
#  262: [100, ['The', 'actual', 'process', 'using', 'system', 'pleasant']],
#  263: [100, ['I', 'fun', 'using', 'system']],
#  264: [101, ['The', 'system', 'makes', 'work', 'interesting']],
#  265: [101, ['Working', 'system', 'fun']],
#  266: [101, ['The', 'system', 'okay', 'jobs', 'kind', 'job', 'I', 'want']],
#  267: [102, ['I', 'like', 'working', 'system']],
#  268: [102,
#   ['I', 'look', 'forward', 'aspects', 'job', 'require', 'use', 'system']],
#  269: [102, ['Using', 'system', 'frustrating']],
#  270: [102,
#   ['Once', 'I', 'start', 'working', 'system', 'I', 'find', 'hard', 'stop']],
#  271: [102, ['I', 'get', 'bored', 'quickly', 'using', 'system']],
#  272: [103, ['I', 'would', 'find', 'system', 'useful', 'job']],
#  273: [103, ['Using', 'system', 'enables', 'accomplish', 'tasks', 'quickly']],
#  274: [103, ['Using', 'system', 'increases', 'productivity']],
#  275: [103,
#   ['If',
#    'I',
#    'use',
#    'system',
#    'I',
#    'increase',
#    'chances',
#    'getting',
#    'raise']],
#  276: [104,
#   ['My', 'interaction', 'system', 'would', 'clear', 'understandable']],
#  277: [104, ['It', 'would', 'easy', 'become', 'skillful', 'using', 'system']],
#  278: [104, ['I', 'would', 'find', 'system', 'easy', 'use']],
#  279: [104, ['Learning', 'operate', 'system', 'easy']],
#  280: [105, ['Using', 'system', 'bad', 'good', 'idea']],
#  281: [105, ['The', 'system', 'makes', 'work', 'interesting']],
#  282: [105, ['Working', 'system', 'fun']],
#  283: [105, ['I', 'like', 'working', 'system']],
#  284: [106,
#   ['People', 'influence', 'behavior', 'think', 'I', 'use', 'system']],
#  285: [106, ['People', 'important', 'think', 'I', 'use', 'system']],
#  286: [106,
#   ['The', 'senior', 'management', 'business', 'helpful', 'use', 'system']],
#  287: [106, ['In', 'general', 'organization', 'supported', 'use', 'system']],
#  288: [107, ['I', 'resources', 'necessary', 'use', 'system']],
#  289: [107, ['I', 'knowledge', 'necessary', 'use', 'system']],
#  290: [107, ['The', 'system', 'compatible', 'systems', 'I', 'use']],
#  291: [107,
#   ['A',
#    'specific',
#    'person',
#    'group',
#    'available',
#    'assistance',
#    'system',
#    'difficulties']],
#  292: [108,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'task',
#    'using',
#    'system',
#    'If',
#    'one',
#    'around',
#    'tell',
#    'I',
#    'go']],
#  293: [108,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'task',
#    'using',
#    'system',
#    'If',
#    'I',
#    'could',
#    'call',
#    'someone',
#    'help',
#    'I',
#    'got',
#    'stuck']],
#  294: [108,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'task',
#    'using',
#    'system',
#    'If',
#    '1',
#    'lot',
#    'time',
#    'complete',
#    'job',
#    'software',
#    'provided']],
#  295: [108,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'task',
#    'using',
#    'system',
#    'If',
#    'I',
#    'built',
#    'help',
#    'facility',
#    'assistance']],
#  296: [109, ['I', 'feel', 'apprehensive', 'using', 'system']],
#  297: [109,
#   ['It',
#    'scares',
#    'think',
#    'I',
#    'could',
#    'lose',
#    'lot',
#    'information',
#    'using',
#    'system',
#    'hitting',
#    'wrong',
#    'key']],
#  298: [109,
#   ['I',
#    'hesitate',
#    'use',
#    'system',
#    'fear',
#    'making',
#    'mistakes',
#    'I',
#    'cannot',
#    'correct']],
#  299: [109, ['The', 'system', 'somewhat', 'intimidating']],
#  300: [110, ['I', 'intend', 'use', 'system', 'next', 'n', 'months']],
#  301: [110,
#   ['I', 'predict', 'I', 'would', 'use', 'system', 'next', 'n', 'months']],
#  302: [110, ['I', 'plan', 'use', 'system', 'next', 'n', 'months']],
#  303: [117, ['Assuming', 'I', 'access', 'system', 'I', 'intend', 'use']],
#  304: [117,
#   ['Given', 'I', 'access', 'system', 'I', 'predict', 'I', 'would', 'use']],
#  305: [118, ['Using', 'system', 'improves', 'performance', 'job']],
#  306: [118, ['Using', 'system', 'job', 'increases', 'productivity']],
#  307: [118, ['Using', 'system', 'enhances', 'effectiveness']],
#  308: [118, ['I', 'find', 'system', 'useful', 'job']],
#  309: [119, ['My', 'interaction', 'system', 'clear', 'understandable']],
#  310: [119, ['Interacting', 'system', 'require', 'lot', 'mental', 'effort']],
#  311: [119, ['I', 'find', 'system', 'easy', 'use']],
#  312: [119, ['I', 'find', 'easy', 'get', 'system', 'I', 'want']],
#  313: [120,
#   ['People', 'influence', 'behavior', 'think', 'I', 'use', 'system']],
#  314: [120, ['People', 'important', 'think', 'I', 'use', 'system']],
#  315: [127,
#   ['If',
#    'I',
#    'suggestion',
#    'improvement',
#    'make',
#    'would',
#    'difficult',
#    'get',
#    'hearing',
#    'manager']],
#  316: [127,
#   ['When',
#    'important',
#    'matter',
#    'comes',
#    'concerns',
#    'manager',
#    'seeks',
#    'ideas',
#    'decision',
#    'made']],
#  317: [127,
#   ['All',
#    'I',
#    'little',
#    'influence',
#    'management',
#    'decisions',
#    'affect',
#    'important',
#    'ways']],
#  318: [127,
#   ['I',
#    'get',
#    'opportunities',
#    'participate',
#    'management',
#    'decisions',
#    'affect',
#    'significant',
#    'aspects',
#    'job']],
#  319: [127,
#   ['Our',
#    'manager',
#    'inclined',
#    'accept',
#    'opinions',
#    'workers',
#    'important',
#    'decisions',
#    'job',
#    'related',
#    'matters']],
#  320: [128, ['I', 'think', 'level', 'pay', 'fair']],
#  321: [128, ['Overall', 'rewards', 'I', 'receive', 'quite', 'fair']],
#  332: [130, ['Time', 'appears', 'go', 'quickly', 'I', 'using', 'Web']],
#  333: [130, ['Sometimes', 'I', 'lose', 'track', 'time', 'I', 'using', 'Web']],
#  334: [130, ['Time', 'flies', 'I', 'using', 'Web']],
#  335: [130,
#   ['Most',
#    'times',
#    'I',
#    'get',
#    'Web',
#    'I',
#    'end',
#    'spending',
#    'time',
#    'I',
#    'planned']],
#  336: [130, ['I', 'often', 'spend', 'time', 'Web', 'I', 'intended']],
#  337: [131, ['While', 'using', 'Web', 'I', 'able', 'block', 'distractions']],
#  338: [131, ['While', 'using', 'Web', 'I', 'absorbed', 'I']],
#  339: [131, ['While', 'Web', 'I', 'immersed', 'task', 'I', 'performing']],
#  340: [131, ['When', 'Web', 'I', 'get', 'distracted', 'attentions', 'easily']],
#  341: [131, ['While', 'Web', 'attention', 'get', 'diverted', 'easily']],
#  342: [132, ['I', 'fun', 'interacting', 'Web']],
#  343: [132, ['Using', 'Web', 'provides', 'lot', 'enjoyment']],
#  344: [132, ['I', 'enjoy', 'using', 'Web']],
#  345: [132, ['Using', 'Web', 'bores']],
#  346: [133, ['When', 'using', 'Web', 'I', 'feel', 'control']],
#  347: [133, ['I', 'feel', 'I', 'control', 'interaction', 'Web']],
#  348: [133, ['The', 'Web', 'allows', 'control', 'computer', 'interaction']],
#  349: [134, ['Using', 'Web', 'excites', 'curiosity']],
#  350: [134, ['Interacting', 'Web', 'makes', 'curious']],
#  351: [134, ['Using', 'Web', 'arouses', 'imagination']],
#  352: [135, ['Learning', 'operate', 'Web', 'easy']],
#  353: [135, ['I', 'find', 'easy', 'get', 'Web', 'I', 'want']],
#  354: [135, ['It', 'easy', 'become', 'skillful', 'using', 'Web']],
#  355: [135, ['I', 'find', 'Web', 'easy', 'use']],
#  356: [136, ['Using', 'Web', 'enhances', 'effectiveness', 'college']],
#  357: [136, ['Using', 'Web', 'enhances', 'productivity']],
#  358: [136, ['I', 'find', 'Web', 'useful', 'college', 'activities']],
#  359: [136, ['Using', 'Web', 'improves', 'performance', 'college']],
#  360: [137,
#   ['If',
#    'I',
#    'heard',
#    'new',
#    'information',
#    'technology',
#    'I',
#    'would',
#    'look',
#    'ways',
#    'experiment']],
#  361: [137,
#   ['In',
#    'general',
#    'I',
#    'hesitant',
#    'try',
#    'new',
#    'information',
#    'technologies']],
#  362: [137,
#   ['Among',
#    'peers',
#    'I',
#    'usually',
#    'first',
#    'try',
#    'new',
#    'information',
#    'technologies']],
#  363: [137, ['I', 'like', 'experiment', 'new', 'information', 'technologies']],
#  364: [138, ['When', 'using', 'Web', 'I', 'Spontaneous']],
#  365: [138, ['When', 'using', 'Web', 'I', 'Imaginative']],
#  366: [138, ['When', 'using', 'Web', 'I', 'Flexible']],
#  367: [138, ['When', 'using', 'Web', 'I', 'Creative']],
#  368: [138, ['When', 'using', 'Web', 'I', 'Playful']],
#  369: [138, ['When', 'using', 'Web', 'I', 'Original']],
#  370: [138, ['When', 'using', 'Web', 'I', 'Inventive']],
#  371: [139, ['I', 'plan', 'use', 'Web', 'future']],
#  372: [139, ['I', 'intend', 'continue', 'using', 'Web', 'future']],
#  373: [139, ['I', 'expect', 'use', 'Web', 'continue', 'future']],
#  374: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'one',
#    'around',
#    'tell',
#    'I',
#    'go']],
#  375: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'never',
#    'used',
#    'package',
#    'like']],
#  376: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'software',
#    'manuals',
#    'reference']],
#  377: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'seen',
#    'someone',
#    'else',
#    'using',
#    'trying']],
#  378: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'could',
#    'call',
#    'someone',
#    'help',
#    'I',
#    'got',
#    'stuck']],
#  379: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'someone',
#    'else',
#    'helped',
#    'get',
#    'started']],
#  380: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'lot',
#    'time',
#    'complete',
#    'job',
#    'software',
#    'provided']],
#  381: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'built',
#    'help',
#    'facility',
#    'assistance']],
#  382: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'someone',
#    'showed',
#    'first']],
#  383: [140,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'used',
#    'similar',
#    'packages',
#    'like',
#    'one',
#    'job']],
#  384: [142,
#   ['I',
#    'feel',
#    'number',
#    'requests',
#    'problems',
#    'complaints',
#    'I',
#    'deal',
#    'expected']],
#  385: [142,
#   ['I', 'feel', 'amount', 'work', 'I', 'interferes', 'well', 'done']],
#  386: [142, ['I', 'feel', 'busy', 'rushed']],
#  387: [142, ['I', 'feel', 'pressured']],
#  388: [143, ['I', 'feel', 'certain', 'much', 'authority', 'I']],
#  389: [143, ['Clear', 'planned', 'goals', 'objectives', 'exist', 'job']],
#  390: [143, ['I', 'know', 'I', 'divided', 'time', 'properly']],
#  391: [143, ['I', 'know', 'responsibilities']],
#  392: [143, ['I', 'know', 'exactly', 'expected']],
#  393: [143, ['Explanation', 'clear', 'done']],
#  394: [144, ['I', 'things', 'done', 'differently']],
#  395: [144, ['I', 'receive', 'assignment', 'without', 'manpower', 'complete']],
#  396: [144, ['I', 'buck', 'rule', 'policy', 'order', 'carry', 'assignment']],
#  397: [144, ['I', 'work', 'two', 'groups', 'operate', 'quite', 'differently']],
#  398: [144, ['I', 'receive', 'incompatible', 'requests', 'two', 'people']],
#  399: [144,
#   ['I', 'things', 'apt', 'accepted', 'one', 'person', 'accepted', 'others']],
#  400: [144,
#   ['I',
#    'receive',
#    'assignment',
#    'without',
#    'adequate',
#    'resources',
#    'materials',
#    'execute']],
#  401: [144, ['I', 'work', 'unnecessary', 'things']],
#  402: [145, ['How', 'likely', 'working', 'company', 'time', 'next', 'year']],
#  403: [145,
#   ['How',
#    'likely',
#    'take',
#    'steps',
#    'next',
#    'year',
#    'secure',
#    'job',
#    'different',
#    'company']],
#  404: [145, ['I', 'company', 'five', 'years']],
#  405: [145,
#   ['I', 'probably', 'look', 'job', 'different', 'company', 'next', 'year']],
#  406: [146, ['I', 'feel', 'emotionally', 'drained', 'work']],
#  407: [146, ['I', 'feel', 'used', 'end', 'work', 'day']],
#  408: [146,
#   ['I',
#    'feel',
#    'fatigued',
#    'I',
#    'get',
#    'morning',
#    'face',
#    'another',
#    'day',
#    'job']],
#  409: [146, ['I', 'feel', 'burned', 'work']],
#  410: [146, ['Working', 'day', 'really', 'strain']],
#  411: [147,
#   ['If',
#    'I',
#    'adopt',
#    'Windows',
#    'would',
#    'enable',
#    'accomplish',
#    'tasks',
#    'quickly']],
#  412: [147,
#   ['If', 'I', 'adopt', 'Windows', 'quality', 'work', 'would', 'improve']],
#  413: [147,
#   ['If', 'I', 'adopt', 'Windows', 'would', 'enhance', 'effectiveness', 'job']],
#  414: [147, ['If', 'I', 'adopt', 'Windows', 'would', 'make', 'job', 'easier']],
#  415: [148,
#   ['Before',
#    'deciding',
#    'whether',
#    'adopt',
#    'Windows',
#    'I',
#    'would',
#    'able',
#    'use',
#    'trial',
#    'basis']],
#  416: [148,
#   ['Before',
#    'deciding',
#    'whether',
#    'adopt',
#    'Windows',
#    'I',
#    'would',
#    'able',
#    'properly',
#    'try']],
#  417: [148,
#   ['I',
#    'would',
#    'permitted',
#    'use',
#    'Windows',
#    'trial',
#    'basis',
#    'long',
#    'enough',
#    'see']],
#  418: [149, ['Learning', 'operate', 'Windows', 'would', 'easy']],
#  419: [149, ['If', 'I', 'adopt', 'Windows', 'would', 'easy', 'use']],
#  420: [149, ['If', 'I', 'adopt', 'Windows', 'would', 'difficult', 'use']],
#  421: [150,
#   ['If', 'I', 'adopt', 'Windows', 'would', 'compatible', 'aspects', 'work']],
#  422: [150, ['If', 'I', 'adopt', 'Windows', 'would', 'fit', 'work', 'style']],
#  423: [150,
#   ['If',
#    'I',
#    'adopt',
#    'Windows',
#    'would',
#    'fit',
#    'well',
#    'way',
#    'I',
#    'like',
#    'work']],
#  424: [151,
#   ['I',
#    'difficulty',
#    'explaining',
#    'adopting',
#    'Windows',
#    'may',
#    'may',
#    'beneficial']],
#  425: [151,
#   ['I',
#    'could',
#    'communicate',
#    'others',
#    'pros',
#    'cons',
#    'adopting',
#    'Windows']],
#  426: [151,
#   ['I', 'difficulty', 'telling', 'others', 'results', 'adopting', 'Windows']],
#  427: [152,
#   ['If',
#    'I',
#    'adopt',
#    'Windows',
#    'would',
#    'give',
#    'high',
#    'status',
#    'organization']],
#  428: [152,
#   ['If',
#    'I',
#    'adopt',
#    'Windows',
#    'I',
#    'would',
#    'prestige',
#    'organization',
#    'people',
#    'yet',
#    'adopted']],
#  429: [152, ['Having', 'Windows', 'status', 'symbol', 'organization']],
#  430: [153,
#   ['In', 'organization', 'one', 'sees', 'Windows', 'many', 'computers']],
#  431: [153,
#   ['In',
#    'organization',
#    'I',
#    'seen',
#    'many',
#    'people',
#    'Windows',
#    'computers']],
#  432: [154,
#   ['All',
#    'things',
#    'considered',
#    'adopting',
#    'Windows',
#    'job',
#    'within',
#    'next',
#    'six',
#    'months',
#    'would',
#    'extremely',
#    'negative',
#    'extremely',
#    'positive']],
#  433: [154,
#   ['All',
#    'things',
#    'considered',
#    'adopting',
#    'Windows',
#    'job',
#    'within',
#    'next',
#    'six',
#    'months',
#    'would',
#    'extremely',
#    'good',
#    'extremely',
#    'bad']],
#  434: [154,
#   ['All',
#    'things',
#    'considered',
#    'adopting',
#    'Windows',
#    'job',
#    'within',
#    'next',
#    'six',
#    'months',
#    'would',
#    'extremely',
#    'harmful',
#    'extremely',
#    'beneficial']],
#  435: [155, ['Top', 'management', 'thinks', 'I', 'adopt', 'Windows']],
#  436: [155, ['My', 'close', 'friends', 'think', 'I', 'adopt', 'Windows']],
#  437: [155,
#   ['My', 'immediate', 'supervisor', 'thinks', 'I', 'adopt', 'Windows']],
#  438: [155, ['My', 'peers', 'think', 'I', 'adopt', 'Windows']],
#  439: [155,
#   ['The', 'name', 'MIS', 'department', 'thinks', 'I', 'adopt', 'Windows']],
#  440: [155,
#   ['Other',
#    'computer',
#    'technical',
#    'specialists',
#    'organization',
#    'think',
#    'I',
#    'adopt',
#    'Windows']],
#  441: [156, ['Most', 'people', 'important', 'think', 'I', 'adopt', 'Windows']],
#  442: [157, ['My', 'boss', 'require', 'adopt', 'Windows']],
#  443: [157,
#   ['Although',
#    'might',
#    'helpful',
#    'adopting',
#    'Windows',
#    'certainly',
#    'compulsory',
#    'job']],
#  444: [158,
#   ['I',
#    'intend',
#    'adopt',
#    'Windows',
#    'job',
#    'within',
#    'next',
#    'six',
#    'months']],
#  445: [158,
#   ['During',
#    'next',
#    'six',
#    'months',
#    'I',
#    'plan',
#    'experiment',
#    'regularly',
#    'use',
#    'Windows',
#    'work']],
#  446: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'one',
#    'around',
#    'tell',
#    'I',
#    'go']],
#  447: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'I',
#    'never',
#    'used',
#    'package',
#    'like']],
#  448: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'I',
#    'software',
#    'manuals',
#    'reference']],
#  449: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'I',
#    'seen',
#    'someone',
#    'else',
#    'using',
#    'trying']],
#  450: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'I',
#    'could',
#    'call',
#    'someone',
#    'help',
#    'I',
#    'got',
#    'stuck']],
#  451: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'someone',
#    'else',
#    'helped',
#    'get',
#    'started']],
#  452: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'I',
#    'lot',
#    'time',
#    'complete',
#    'job',
#    'software',
#    'provided']],
#  453: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'I',
#    'built',
#    'help',
#    'facility',
#    'assistance']],
#  454: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'someone',
#    'showed',
#    'first']],
#  455: [162,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'I',
#    'used',
#    'similar',
#    'packages',
#    'one',
#    'job']],
#  456: [169, ['If', 'I', 'use', 'computer', 'I', 'better', 'organized']],
#  457: [169,
#   ['If', 'I', 'use', 'computer', 'I', 'increase', 'effectiveness', 'job']],
#  458: [169,
#   ['If',
#    'I',
#    'use',
#    'computer',
#    'I',
#    'spend',
#    'less',
#    'time',
#    'routine',
#    'job',
#    'tasks']],
#  459: [169,
#   ['If', 'I', 'use', 'computer', 'I', 'increase', 'quality', 'output', 'job']],
#  460: [169,
#   ['If',
#    'I',
#    'use',
#    'computer',
#    'I',
#    'increase',
#    'quantity',
#    'output',
#    'amount',
#    'effort']],
#  461: [169,
#   ['If',
#    'I',
#    'use',
#    'computer',
#    'I',
#    'less',
#    'reliant',
#    'clerical',
#    'support',
#    'staff']],
#  462: [170,
#   ['If', 'I', 'use', 'computer', 'co', 'workers', 'perceive', 'competent']],
#  463: [170,
#   ['If', 'I', 'use', 'computer', 'I', 'increase', 'sense', 'accomplishment']],
#  464: [170,
#   ['If',
#    'I',
#    'use',
#    'computer',
#    'I',
#    'increase',
#    'chances',
#    'obtaining',
#    'promotion']],
#  465: [170,
#   ['If', 'I', 'use', 'computer', 'I', 'seen', 'higher', 'status', 'peers']],
#  466: [170,
#   ['If',
#    'I',
#    'use',
#    'computer',
#    'I',
#    'increase',
#    'chances',
#    'getting',
#    'raise']],
#  467: [171, ['I', 'like', 'working', 'computers']],
#  468: [171,
#   ['I', 'look', 'forward', 'aspects', 'job', 'require', 'use', 'computer']],
#  469: [171,
#   ['Once', 'I', 'start', 'working', 'computer', 'I', 'find', 'hard']],
#  470: [171, ['Using', 'computer', 'frustrating']],
#  471: [171, ['I', 'get', 'bored', 'quickly', 'working', 'computer']],
#  472: [172, ['I', 'feel', 'apprehensive', 'using', 'computers']],
#  473: [172,
#   ['It',
#    'scares',
#    'think',
#    'I',
#    'could',
#    'cause',
#    'computer',
#    'destroy',
#    'large',
#    'amount',
#    'information',
#    'hitting',
#    'wrong',
#    'key']],
#  474: [172,
#   ['I',
#    'hesitate',
#    'use',
#    'computer',
#    'fear',
#    'making',
#    'mistakes',
#    'I',
#    'cannot',
#    'correct']],
#  475: [172, ['Computers', 'somewhat', 'intimidating']],
#  501: [178,
#   ['Sharing',
#    'knowledge',
#    'makes',
#    'lose',
#    'unique',
#    'value',
#    'organization']],
#  502: [178,
#   ['Sharing', 'knowledge', 'makes', 'lose', 'power', 'base', 'organization']],
#  503: [178,
#   ['Sharing',
#    'knowledge',
#    'makes',
#    'lose',
#    'knowledge',
#    'makes',
#    'stand',
#    'respect',
#    'others']],
#  504: [178,
#   ['Sharing', 'knowledge', 'makes', 'lose', 'knowledge', 'one', 'else']],
#  507: [180, ['I', 'time', 'enter', 'knowledge']],
#  508: [180, ['It', 'laborious', 'codify', 'knowledge']],
#  509: [180, ['The', 'effort', 'high', 'codify', 'knowledge']],
#  510: [180,
#   ['I',
#    'worried',
#    'I',
#    'share',
#    'knowledge',
#    'I',
#    'spend',
#    'additional',
#    'time',
#    'answering',
#    'follow',
#    'questions']],
#  511: [180,
#   ['I',
#    'afraid',
#    'submission',
#    'evoke',
#    'additional',
#    'clarifications',
#    'requests',
#    'assistance']],
#  527: [184,
#   ['It',
#    'important',
#    'get',
#    'better',
#    'work',
#    'assignment',
#    'I',
#    'share',
#    'knowledge']],
#  528: [184, ['It', 'important', 'promoted', 'I', 'share', 'knowledge']],
#  529: [184,
#   ['It', 'important', 'get', 'higher', 'salary', 'I', 'share', 'knowledge']],
#  530: [184,
#   ['It', 'important', 'get', 'higher', 'bonus', 'I', 'share', 'knowledge']],
#  531: [184,
#   ['It', 'important', 'get', 'job', 'security', 'I', 'share', 'knowledge']],
#  532: [185,
#   ['Sharing', 'knowledge', 'improves', 'image', 'within', 'organization']],
#  533: [185, ['People', 'organization', 'share', 'knowledge', 'prestige']],
#  534: [185, ['Sharing', 'knowledge', 'improves', 'others', 'recognition']],
#  535: [185,
#   ['When', 'I', 'share', 'knowledge', 'people', 'I', 'work', 'respect']],
#  536: [185, ['When', 'I', 'share', 'knowledge', 'superiors', 'praise']],
#  537: [186,
#   ['When',
#    'I',
#    'share',
#    'knowledge',
#    'I',
#    'believe',
#    'I',
#    'get',
#    'answer',
#    'giving',
#    'answer']],
#  538: [186,
#   ['When',
#    'I',
#    'share',
#    'knowledge',
#    'I',
#    'expect',
#    'somebody',
#    'respond',
#    'I',
#    'need']],
#  539: [186,
#   ['When',
#    'I',
#    'contribute',
#    'knowledge',
#    'I',
#    'expect',
#    'get',
#    'back',
#    'knowledge',
#    'I',
#    'need']],
#  540: [186,
#   ['When',
#    'I',
#    'share',
#    'knowledge',
#    'I',
#    'believe',
#    'queries',
#    'knowledge',
#    'answered',
#    'future']],
#  541: [187,
#   ['Extent',
#    'partner',
#    'company',
#    'make',
#    'joint',
#    'decisions',
#    'planning',
#    'marketing',
#    'programs']],
#  542: [187,
#   ['Extent',
#    'partner',
#    'company',
#    'make',
#    'joint',
#    'decisions',
#    'analyzing',
#    'market',
#    'trends']],
#  543: [187,
#   ['Extent',
#    'partner',
#    'company',
#    'make',
#    'joint',
#    'decisions',
#    'analyzing',
#    'response',
#    'marketing',
#    'promotions']],
#  544: [187,
#   ['Extent',
#    'partner',
#    'company',
#    'make',
#    'joint',
#    'decisions',
#    'planning',
#    'new',
#    'market',
#    'creation']],
#  545: [187,
#   ['Extent',
#    'partner',
#    'company',
#    'make',
#    'joint',
#    'decisions',
#    'planning',
#    'demand',
#    'development']],
#  546: [188,
#   ['I',
#    'confidence',
#    'ability',
#    'provide',
#    'knowledge',
#    'others',
#    'organization',
#    'consider',
#    'valuable']],
#  547: [188,
#   ['I',
#    'expertise',
#    'needed',
#    'provide',
#    'valuable',
#    'knowledge',
#    'organization']],
#  548: [188,
#   ['It',
#    'really',
#    'make',
#    'difference',
#    'whether',
#    'I',
#    'add',
#    'knowledge',
#    'others',
#    'likely',
#    'share']],
#  549: [188, ['Most', 'employees', 'provide', 'valuable', 'knowledge', 'I']],
#  550: [189, ['I', 'enjoy', 'sharing', 'knowledge', 'others']],
#  551: [189, ['I', 'enjoy', 'helping', 'others', 'sharing', 'knowledge']],
#  552: [189,
#   ['It', 'feels', 'good', 'help', 'someone', 'else', 'sharing', 'knowledge']],
#  553: [189, ['Sharing', 'knowledge', 'others', 'gives', 'pleasure']],
#  554: [190,
#   ['I',
#    'believe',
#    'people',
#    'organization',
#    'give',
#    'credit',
#    'knowledge',
#    'due']],
#  555: [190,
#   ['I',
#    'believe',
#    'people',
#    'organization',
#    'use',
#    'unauthorized',
#    'knowledge']],
#  556: [190,
#   ['I',
#    'believe',
#    'people',
#    'organization',
#    'use',
#    'knowledge',
#    'appropriately']],
#  557: [190,
#   ['I', 'believe', 'people', 'organization', 'share', 'best', 'knowledge']],
#  558: [191,
#   ['The',
#    'processes',
#    'conducted',
#    'conjunction',
#    'partner',
#    'company',
#    'divided',
#    'clearly',
#    'understood',
#    'activities',
#    'performed',
#    'partner',
#    'company']],
#  559: [191,
#   ['The',
#    'output',
#    'requirements',
#    'partner',
#    'company',
#    'company',
#    'requirements',
#    'partner',
#    'company',
#    'precisely',
#    'specified',
#    'understood']],
#  560: [191,
#   ['The',
#    'activities',
#    'performed',
#    'company',
#    'partner',
#    'company',
#    'performed',
#    'simultaneously',
#    'large',
#    'extent']],
#  561: [192, ['There', 'norm', 'cooperation', 'organization']],
#  562: [192, ['There', 'norm', 'collaboration', 'organization']],
#  563: [192, ['There', 'norm', 'teamwork', 'organization']],
#  564: [192,
#   ['There', 'willingness', 'value', 'respond', 'diversity', 'organization']],
#  565: [192,
#   ['There', 'norm', 'openness', 'conflicting', 'views', 'organization']],
#  566: [192, ['There', 'norm', 'tolerance', 'mistakes', 'organization']],
#  567: [193,
#   ['Extent',
#    'business',
# ...
#    'expenditure',
#    'cycle',
#    'application',
#    'developed',
#    'extent',
#    'desire',
#    'participate',
#    'following',
#    'activity',
#    'Creating',
#    'user',
#    'procedural',
#    'manuals']],
#  1109: [421, ['Do', 'feel', 'really', 'part', 'work', 'group']],
#  1110: [421,
#   ['If',
#    'chance',
#    'kind',
#    'work',
#    'another',
#    'student',
#    'work',
#    'group',
#    'would',
#    'feel',
#    'moving']],
#  1111: [421,
#   ['How',
#    'group',
#    'compare',
#    'student',
#    'groups',
#    'fo',
#    'following',
#    'points',
#    'The',
#    'way',
#    'people',
#    'get',
#    'along',
#    'together']],
#  1112: [421,
#   ['How',
#    'group',
#    'compare',
#    'student',
#    'groups',
#    'following',
#    'points',
#    'The',
#    'way',
#    'people',
#    'work',
#    'together']],
#  1113: [421,
#   ['How',
#    'group',
#    'compare',
#    'student',
#    'groups',
#    'following',
#    'points',
#    'The',
#    'way',
#    'people',
#    'help']],
#  1114: [423,
#   ['Were',
#    'group',
#    'members',
#    'well',
#    'committed',
#    'goals',
#    'objectives',
#    'group',
#    'meeting']],
#  1115: [423,
#   ['To', 'extent', 'trust', 'exhibited', 'within', 'group', 'meeting']],
#  1116: [423,
#   ['Did', 'members', 'strong', 'sense', 'belonging', 'group', 'meeting']],
#  1117: [423,
#   ['Did',
#    'group',
#    'members',
#    'recognize',
#    'respect',
#    'individual',
#    'differences',
#    'contributions',
#    'meeting']],
#  1118: [423,
#   ['Were',
#    'group',
#    'members',
#    'open',
#    'frank',
#    'expressing',
#    'ideas',
#    'feelings',
#    'meeting']],
#  1119: [427,
#   ['Overall', 'I', 'personally', 'satisfied', 'decision', 'meeting']],
#  1120: [427,
#   ['This',
#    'group',
#    'produced',
#    'effective',
#    'valuable',
#    'results',
#    'meeting']],
#  1121: [427, ['I', 'agree', 'final', 'decision', 'group']],
#  1122: [427, ['Overall', 'quality', 'meeting', 'high']],
#  1126: [441,
#   ['I', 'get', 'data', 'current', 'enough', 'meet', 'business', 'needs']],
#  1127: [441, ['The', 'data', 'date', 'enough', 'purposes']],
#  1132: [442,
#   ['It',
#    'easy',
#    'find',
#    'data',
#    'corporation',
#    'maintains',
#    'given',
#    'subject']],
#  1133: [442,
#   ['It',
#    'easy',
#    'locate',
#    'corporate',
#    'divisional',
#    'data',
#    'particular',
#    'issue',
#    'even',
#    'I',
#    'used',
#    'data']],
#  1136: [446,
#   ['Data', 'would', 'useful', 'unavailable', 'I', 'right', 'authorization']],
#  1137: [446,
#   ['Getting',
#    'authorization',
#    'access',
#    'data',
#    'would',
#    'useful',
#    'job',
#    'time',
#    'consuming',
#    'difficult']],
#  1138: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'one',
#    'around',
#    'tell',
#    'I',
#    'go']],
#  1139: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'never',
#    'used',
#    'package',
#    'like']],
#  1140: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'software',
#    'manuals',
#    'reference']],
#  1141: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'seen',
#    'someone',
#    'else',
#    'using',
#    'trying']],
#  1142: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'could',
#    'call',
#    'someone',
#    'help',
#    'I',
#    'got',
#    'stuck']],
#  1143: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'someone',
#    'else',
#    'helped',
#    'get',
#    'started']],
#  1144: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'lot',
#    'time',
#    'complete',
#    'job',
#    'software',
#    'provided']],
#  1145: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'built',
#    'help',
#    'facility',
#    'assistance']],
#  1146: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'someone',
#    'showed',
#    'first']],
#  1147: [447,
#   ['I',
#    'could',
#    'complete',
#    'job',
#    'using',
#    'software',
#    'package',
#    'I',
#    'used',
#    'similar',
#    'packages',
#    'one',
#    'job']],
#  1148: [448,
#   ['There',
#    'times',
#    'I',
#    'find',
#    'supposedly',
#    'equivalent',
#    'data',
#    'two',
#    'different',
#    'sources',
#    'inconsistent']],
#  1149: [448,
#   ['Sometimes',
#    'difficult',
#    'compare',
#    'consolidate',
#    'data',
#    'two',
#    'different',
#    'sources',
#    'data',
#    'defined',
#    'differently']],
#  1150: [448,
#   ['When',
#    'necessary',
#    'compare',
#    'consolidate',
#    'data',
#    'different',
#    'sources',
#    'I',
#    'find',
#    'may',
#    'unexpected',
#    'difficult',
#    'inconsistencies']],
#  1151: [449,
#   ['IS',
#    'knowledge',
#    'meets',
#    'production',
#    'schedules',
#    'report',
#    'delivery',
#    'running',
#    'scheduled',
#    'jobs']],
#  1152: [449,
#   ['Regular',
#    'IS',
#    'activities',
#    'printed',
#    'report',
#    'delivery',
#    'running',
#    'scheduled',
#    'jobs',
#    'completed',
#    'time']],
#  1153: [450, ['I', 'count', 'system', 'available', 'I', 'need']],
#  1154: [450,
#   ['The',
#    'computer',
#    'systems',
#    'I',
#    'use',
#    'subject',
#    'unexpected',
#    'inconvenient',
#    'times',
#    'makes',
#    'harder',
#    'work']],
#  1155: [450,
#   ['The',
#    'computer',
#    'systems',
#    'I',
#    'use',
#    'subject',
#    'frequent',
#    'problems',
#    'crashes']],
#  1163: [452,
#   ['It', 'easy', 'learn', 'use', 'computer', 'systems', 'I', 'need']],
#  1164: [452,
#   ['The', 'computer', 'systems', 'I', 'use', 'convenient', 'easy', 'use']],
#  1180: [455,
#   ['The',
#    'IS',
#    'people',
#    'deal',
#    'understand',
#    'day',
#    'day',
#    'objectives',
#    'work',
#    'group',
#    'mission',
#    'within',
#    'company']],
#  1181: [455,
#   ['My',
#    'work',
#    'group',
#    'feels',
#    'IS',
#    'personnel',
#    'communicate',
#    'us',
#    'familiar',
#    'business',
#    'terms',
#    'consistent']],
#  1190: [457, ['IS', 'date', 'hardware', 'software']],
#  1191: [457, ['IS', 'physical', 'facilities', 'visually', 'appealing']],
#  1192: [457, ['IS', 'employees', 'well', 'dressed', 'neat', 'appearance']],
#  1193: [457,
#   ['The',
#    'appearance',
#    'physical',
#    'facilities',
#    'IS',
#    'keeping',
#    'kind',
#    'services',
#    'provided']],
#  1194: [458, ['I', 'like', 'working', 'computers']],
#  1195: [458,
#   ['Once', 'I', 'get', 'working', 'computer', 'I', 'find', 'hard', 'stop']],
#  1196: [459, ['I', 'feel', 'apprehensive', 'using', 'computers']],
#  1197: [460, ['When', 'IS', 'promises', 'something', 'certain', 'time']],
#  1198: [460,
#   ['When',
#    'users',
#    'problem',
#    'IS',
#    'shows',
#    'sincere',
#    'interest',
#    'solving']],
#  1199: [460, ['IS', 'dependable']],
#  1200: [460, ['IS', 'provides', 'services', 'times', 'promises']],
#  1201: [460, ['IS', 'insists', 'error', 'free', 'records']],
#  1206: [467, ['IS', 'tell', 'users', 'exactly', 'services', 'performed']],
#  1207: [467, ['IS', 'employees', 'give', 'prompt', 'service', 'users']],
#  1208: [467, ['IS', 'employees', 'always', 'willing', 'help', 'users']],
#  1209: [467,
#   ['IS', 'employees', 'never', 'busy', 'respond', 'users', 'requests']],
#  1210: [470,
#   ['The', 'behavior', 'IS', 'employees', 'instills', 'confidence', 'users']],
#  1211: [470, ['Users', 'feel', 'safe', 'transactions', 'IS', 'employees']],
#  1212: [470, ['IS', 'employees', 'consistently', 'courteous', 'users']],
#  1213: [470, ['IS', 'employees', 'knowledge', 'job', 'well']],
#  1214: [473, ['IS', 'gives', 'users', 'individual', 'attention']],
#  1215: [473, ['IS', 'operating', 'hours', 'convenient', 'users']],
#  1216: [473, ['IS', 'employees', 'give', 'users', 'personal', 'attention']],
#  1217: [473, ['IS', 'users', 'best', 'interests', 'heart']],
#  1218: [473, ['Employees', 'IS', 'understand', 'specific', 'needs', 'users']],
#  1226: [483,
#   ['When',
#    'excellent',
#    'information',
#    'services',
#    'promise',
#    'something',
#    'certain',
#    'time']],
#  1227: [483,
#   ['Excellent',
#    'information',
#    'services',
#    'perform',
#    'service',
#    'right',
#    'first',
#    'time']],
#  1228: [483,
#   ['Excellent',
#    'information',
#    'services',
#    'provide',
#    'services',
#    'time',
#    'promise']],
#  1235: [485,
#   ['When',
#    'information',
#    'services',
#    'promises',
#    'something',
#    'certain',
#    'time']],
#  1236: [485,
#   ['Our',
#    'information',
#    'services',
#    'performs',
#    'services',
#    'right',
#    'first',
#    'time']],
#  1237: [485,
#   ['Our',
#    'information',
#    'services',
#    'provides',
#    'services',
#    'time',
#    'promises']],
#  1238: [486,
#   ['I', 'feel', 'I', 'control', 'computer', 'rather', 'computers', 'control']],
#  1239: [486,
#   ['Computers', 'dehumanize', 'society', 'treating', 'everyone', 'number']],
#  1240: [486, ['I', 'feel', 'helpless', 'using', 'computer']],
#  1241: [486, ['Computers', 'potential', 'control', 'lives']],
#  1242: [486,
#   ['I',
#    'usually',
#    'make',
#    'work',
#    'fit',
#    'computer',
#    'rather',
#    'computer',
#    'fit',
#    'work']],
#  1243: [487, ['I', 'clearly', 'understand', 'input', 'computers', 'want']],
#  1244: [487,
#   ['Working', 'computers', 'complicated', 'difficult', 'understand', 'going']],
#  1245: [487,
#   ['Computer', 'terminology', 'sounds', 'like', 'confusing', 'jargon']],
#  1246: [487, ['I', 'understand', 'computer', 'output']],
#  1247: [488,
#   ['Employees',
#    'excellent',
#    'information',
#    'services',
#    'give',
#    'prompt',
#    'service',
#    'users']],
#  1248: [488,
#   ['Employees',
#    'excellent',
#    'information',
#    'services',
#    'always',
#    'willing',
#    'help',
#    'users']],
#  1249: [488,
#   ['Employees',
#    'excellent',
#    'information',
#    'services',
#    'never',
#    'busy',
#    'respond',
#    'users']],
#  1253: [490,
#   ['Employees', 'information', 'services', 'give', 'prompt', 'service']],
#  1254: [490,
#   ['Employees', 'information', 'services', 'always', 'willing', 'help']],
#  1255: [490,
#   ['Employees',
#    'information',
#    'services',
#    'never',
#    'busy',
#    'respond',
#    'requests']],
#  1259: [492, ['Computers', 'encourage', 'unethical', 'practices']],
#  1260: [492, ['I', 'trust', 'computer', 'suppliers']],
#  1261: [492,
#   ['There',
#    'big',
#    'discrepancy',
#    'computer',
#    'software',
#    'qualities',
#    'claimed',
#    'computer',
#    'elite',
#    'real',
#    'qualities']],
#  1262: [493, ['Found', 'course', 'good', 'learning', 'experience']],
#  1263: [493, ['Learned', 'class', 'format']],
#  1264: [493, ['Course', 'boring']],
#  1265: [493, ['Student', 'comments', 'useful']],
#  1266: [494, ['I', 'get', 'along', 'well', 'computer', 'professionals']],
#  1267: [494,
#   ['Computer', 'professionals', 'naturally', 'friendly', 'helpful']],
#  1268: [494, ['I', 'like', 'associated', 'computer', 'department']],
#  1269: [495, ['Group', 'work', 'contributed', 'course', 'quality']],
#  1270: [495, ['Group', 'work', 'contributed', 'learning']],
#  1271: [495, ['Group', 'work', 'fun']],
#  1272: [496,
#   ['The',
#    'behavior',
#    'employees',
#    'excellent',
#    'information',
#    'services',
#    'instill',
#    'confidence',
#    'users']],
#  1273: [496,
#   ['Employees',
#    'excellent',
#    'information',
#    'services',
#    'consistently',
#    'courteous',
#    'users']],
#  1274: [496,
#   ['Employees',
#    'excellent',
#    'information',
#    'services',
#    'knowledge',
#    'answer',
#    'users',
#    'questions']],
#  1275: [497, ['Using', 'computer', 'enjoyable', 'experience']],
#  1276: [497,
#   ['If', 'I', 'use', 'computer', 'would', 'probably', 'trouble', 'worth']],
#  1277: [497, ['I', 'sometimes', 'get', 'nervous', 'thinking', 'computers']],
#  1278: [499,
#   ['The',
#    'behavior',
#    'employees',
#    'information',
#    'services',
#    'instills',
#    'confidence']],
#  1279: [499,
#   ['Employees', 'information', 'services', 'consistently', 'courteous']],
#  1280: [499,
#   ['Employees',
#    'information',
#    'services',
#    'knowledge',
#    'answer',
#    'questions']],
#  1281: [500, ['I', 'would', 'use', 'computers', 'even', 'expected']],
#  1282: [500, ['I', 'care', 'people', 'say', 'computers']],
#  1283: [500, ['Society', 'values', 'computers', 'highly']],
#  1284: [501,
#   ['Excellent',
#    'information',
#    'services',
#    'give',
#    'users',
#    'individual',
#    'attention']],
#  1285: [501,
#   ['Excellent',
#    'information',
#    'services',
#    'employees',
#    'give',
#    'users',
#    'personal',
#    'attention']],
#  1286: [501,
#   ['Excellent',
#    'information',
#    'services',
#    'user',
#    'best',
#    'interests',
#    'heart']],
#  1287: [501,
#   ['The',
#    'employees',
#    'excellent',
#    'information',
#    'services',
#    'understand',
#    'specific',
#    'needs',
#    'users']],
#  1288: [502,
#   ['Our', 'information', 'services', 'gives', 'individual', 'attention']],
#  1289: [502,
#   ['Our',
#    'information',
#    'services',
#    'employees',
#    'give',
#    'personal',
#    'attention']],
#  1290: [502, ['Our', 'information', 'services', 'best', 'interests', 'heart']],
#  1291: [502,
#   ['Employees', 'information', 'services', 'understand', 'specific', 'needs']],
#  1292: [503,
#   ['Information',
#    'Systems',
#    'Data',
#    'Processing',
#    'staff',
#    'kept',
#    'informed']],
#  1293: [503,
#   ['I',
#    'formally',
#    'reviewed',
#    'work',
#    'done',
#    'Information',
#    'Systems',
#    'Data',
#    'Processing']],
#  1294: [503,
#   ['I',
#    'formally',
#    'approved',
#    'work',
#    'done',
#    'Information',
#    'Systems',
#    'Data',
#    'Processing']],
#  1309: [507, ['I', 'responsibility', 'select', 'hardware', 'software']],
#  1310: [507, ['I', 'responsibility', 'estimating', 'development', 'costs']],
#  1311: [507, ['I', 'responsibility', 'request', 'additional', 'funds']],
#  1312: [507, ['I', 'leader', 'project', 'team']],
#  1315: [511, ['I', 'defined', 'helped', 'define', 'report', 'formats']],
#  1316: [511, ['I', 'created', 'user', 'manual']],
#  1317: [511, ['I', 'designed', 'user', 'training', 'program']],
#  1327: [514,
#   ['How',
#    'would',
#    'rate',
#    'chances',
#    'promotion',
#    'higher',
#    'position',
#    'sometime',
#    'career',
#    'company']],
#  1347: [529, ['I', 'concerned', 'threats', 'personal', 'privacy']],
#  1348: [530,
#   ['How',
#    'useful',
#    'computer',
#    'based',
#    'information',
#    'annual',
#    'budget',
#    'preparation',
#    'process']],
#  1349: [530,
#   ['How',
#    'useful',
#    'computer',
#    'based',
#    'information',
#    'day',
#    'day',
#    'expenditure',
#    'decisions']],
#  1350: [530,
#   ['How',
#    'useful',
#    'computer',
#    'based',
#    'information',
#    'managing',
#    'financial',
#    'resources',
#    'order',
#    'prevent',
#    'overspending']],
#  1351: [530,
#   ['How',
#    'useful',
#    'computer',
#    'based',
#    'information',
#    'identifying',
#    'might',
#    'slack',
#    'resources',
#    'could',
#    'purposes']],
#  1352: [531,
#   ['Consumers', 'lost', 'control', 'personal', 'information', 'used']],
#  1353: [531,
#   ['Americans',
#    'begin',
#    'surrendering',
#    'privacy',
#    'day',
#    'open',
#    'first',
#    'charge',
#    'account']],
#  1354: [532,
#   ['How',
#    'useful',
#    'computer',
#    'based',
#    'information',
#    'evaluating',
#    'relative',
#    'performance',
#    'subunits',
#    'within',
#    'department',
#    'division']],
#  1355: [532,
#   ['How',
#    'useful',
#    'computer',
#    'based',
#    'information',
#    'identifying',
#    'problems',
#    'abuses',
#    'inefficiencies',
#    'unit',
#    'supervise']],
#  1356: [532,
#   ['How',
#    'useful',
#    'computer',
#    'based',
#    'information',
#    'providing',
#    'indicators',
#    'departmental',
#    'subunit',
#    'performance',
#    'e',
#    'g',
#    'employee',
#    'turnover',
#    'absenteeism',
#    'service',
#    'needs',
#    'facility',
#    'usage',
#    'cost',
#    'programs']],
#  1357: [533,
#   ['Companies',
#    'use',
#    'personal',
#    'information',
#    'purpose',
#    'one',
#    'authorized']],
#  1358: [533,
#   ['A',
#    'company',
#    'share',
#    'personal',
#    'information',
#    'without',
#    'permission']],
#  1359: [534,
#   ['The',
#    'computer',
#    'provide',
#    'precise',
#    'information',
#    'I',
#    'need',
#    'work']],
#  1360: [534,
#   ['The',
#    'computer',
#    'makes',
#    'new',
#    'information',
#    'available',
#    'previously',
#    'available']],
#  1361: [534,
#   ['The',
#    'computer',
#    'provides',
#    'date',
#    'information',
#    'available',
#    'manual',
#    'files']],
#  ...}

# %%
import re
newtest = {}
dictionary = {x[0]: { x[1] : x[2:] } for x in df_test.itertuples(index=False)}
for key, item in dictionary.items():
    #print(key, item)
    for key2, item2 in item.items():
        itemslist = (list(item2))  
        words = ([word for sentence in itemslist for word in tokenizer.tokenize(sentence)])
        for word in words:
            if word not in Embeddings1.keys():
                words.remove(word)
        filtered_sentence = [w for w in words if not w in stop_words]
        #print(key, key2)
        newtest[key] =  [key2, filtered_sentence]
# Out:
# {1: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'understanding',
#    'module',
#    'integrates',
#    'modules',
#    'systems']],
#  2: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'ability',
#    'ask',
#    'penetrating',
#    'questions',
#    'module']],
#  3: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'improved',
#    'knowledge',
#    'module']],
#  4: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'knowledge',
#    'module',
#    'training',
#    'documents',
#    'end',
#    'users']],
#  5: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'increased',
#    'knowledge',
#    'setting',
#    'configuration',
#    'tables',
#    'support',
#    'client',
#    'business',
#    'processes']],
#  6: [14,
#   ['During',
#    'Purchasing',
#    'module',
#    'implementation',
#    'project',
#    'interactions',
#    'Consultant',
#    'William',
#    'improved',
#    'ability',
#    'develop',
#    'test',
#    'scripts',
#    'module']],
#  8: [15,
#   ['Client',
#    'Alisha',
#    'vision',
#    'implementation',
#    'Purchasing',
#    'module',
#    'project',
#    'trying',
#    'achieve']],
#  10: [15,
#   ['Client',
#    'Alisha',
#    'clear',
#    'understanding',
#    'goals',
#    'tasks',
#    'responsibilities',
#    'implementing',
#    'Purchasing',
#    'module']],
#  11: [15,
#   ['Client',
#    'Alisha',
#    'technical',
#    'competence',
#    'absorb',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  12: [15,
#   ['Client',
#    'Alisha',
#    'managerial',
#    'competence',
#    'absorb',
#    'business',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  26: [17,
#   ['Communication', 'Consultant', 'William', 'Very', 'easy', 'demanding']],
#  27: [17, ['Communication', 'Client', 'Alisha', 'Very', 'easy', 'demanding']],
#  28: [17,
#   ['Collaboration',
#    'Consultant',
#    'William',
#    'Is',
#    'sought',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Is',
#    'often',
#    'avoided',
#    'Occurs',
#    'I',
#    'alternative']],
#  29: [17,
#   ['Collaboration',
#    'Client',
#    'Alisha',
#    '2',
#    'Is',
#    'sought',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Is',
#    'often',
#    'avoided',
#    'Occurs',
#    'I',
#    'alternative']],
#  30: [17,
#   ['Collaboration',
#    'Consultant',
#    'William',
#    'Is',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'usually',
#    'avoided',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Occurs',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'alternative']],
#  31: [17,
#   ['Collaboration',
#    'Client',
#    'Alisha',
#    'Is',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'well',
#    'received',
#    'sought',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Is',
#    'usually',
#    'avoided',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'Occurs',
#    'Consultant',
#    'William',
#    'Client',
#    'Alisha',
#    'alternative']],
#  32: [18,
#   ['I',
#    'enjoy',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module']],
#  33: [18,
#   ['The',
#    'difficult',
#    'understand',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    'I',
#    'enjoy',
#    'learning',
#    '1']],
#  34: [18,
#   ['I',
#    'enjoy',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    'completely',
#    'new']],
#  35: [18,
#   ['I',
#    'feel',
#    'I',
#    'personally',
#    'benefitting',
#    'learning',
#    'business',
#    'technical',
#    'knowledge',
#    'Purchasing',
#    'module',
#    '1',
#    '2']]}

# %%
table = []
start = time.time()
random.seed(1)
for key, value in new.items():
    for key2, values2 in new.items():
        if key >= key2:
            continue
        #if key2 >= key:
        if value[0]!=values2[0]:
            foundnum=random.randint(1,3167)
            if foundnum == 1:
                table.append([key, key2,value[0]* values2[0],0, calculateSentenceSim1(value[1],values2[1])])
        else:
            table.append([key, key2,value[0]* values2[0],1, calculateSentenceSim1(value[1],values2[1])])

# %%
#not to be used
tabletest = []
start = time.time()
random.seed(1)
for key, value in newtest.items():
    for key2, values2 in newtest.items():
        if key >= key2:
            continue
        if value[0]!=values2[0]:
            foundnum=random.randint(1,100000)
            if foundnum == 1:
                table.append([key, key2,value[0]* values2[0],0, calculateSentenceSim1(value[1],values2[1])])
        else:
            table.append([key, key2,value[0]* values2[0],1, calculateSentenceSim1(value[1],values2[1])])
       
    if len(table) > 10000:
        print(time.time() - start)
# Out:
# 0.21953582763671875
# 0.38275575637817383
# 0.5477049350738525
# 0.6963858604431152
# 0.8742086887359619
# 1.0662457942962646
# 1.2448749542236328
# 1.3829541206359863
# 1.5241920948028564
# 1.642535924911499
# 1.6997849941253662
# 1.768155813217163
# 1.8907039165496826
# 1.986595869064331
# 2.132564067840576
# 2.211120843887329
# 2.224491834640503
# 2.2458279132843018
# 2.2599220275878906
# 2.260037899017334
# []

# %% [markdown]
# ### 50212 trues

# %%
list1 = []
list1.append([])
list1 = []
list1.append([])
z = 0
for x in table:
    list2 = []
    for y in x[4]:
        
        #print(y)
        #print(x[0],x[1],x[2], x[3],y)
        list2.append(y)
        #for m in list2:
            #list3.append(m)
            #list3[z].extend(m)
    list1[z].append(x[0])
    list1[z].append(x[1])
    list1[z].append(x[2])
    list1[z].append(x[3])
    list1[z].extend(list2)
    list1[z]
    z += 1
    list1.append([])
list1[0]
#list3
# Out:
# [1,
#  2,
#  196,
#  1,
#  90.67004846841427,
#  83.51282078919309,
#  83.51282078919309,
#  66.90128468486736,
#  18.08809080725074,
#  15.173966206060578,
#  12.528993366088304,
#  12.489277724104978,
#  7.179484606412504,
#  5.870747074852751,
#  5.870747074852751,
#  5.870747074852751,
#  5.870747074852751,
#  2.0489165883909246,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
tableDF2 = pd.DataFrame(list1)

# %%
tableDF2 = tableDF2.rename(columns = {0:'ItemId1', 1:'ItemId2',2:'VId',3:'Target'})
tableDF2.head(7)
# Out:
#    ItemId1  ItemId2       VId  Target          4          5          6  \
# 0      1.0      2.0     196.0     1.0  90.670048  83.512821  83.512821
# 1      1.0      3.0     196.0     1.0  90.670048  83.512821  83.512821
# 2      1.0      4.0     196.0     1.0  90.670048  83.512821  83.512821
# 3      1.0      5.0     196.0     1.0  90.670048  83.512821  66.901285
# 4      1.0      6.0     196.0     1.0  90.670048  83.512821  83.512821
# 5      1.0  28108.0  387576.0     0.0  39.029185  34.419165  26.188625
# 6      1.0  42807.0  333060.0     0.0  17.439168  15.522113  14.568079
#
#            7          8          9 ...  57  58  59  60  61  62  63  64  65  66
# 0  66.901285  18.088091  15.173966 ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1  66.901285  26.188625  15.173966 ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2  66.901285  26.188625  15.173966 ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3  49.681743  28.967924  26.188625 ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4  66.901285  39.304760  15.652012 ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 5  16.886617   7.956144   4.871312 ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6  10.441964   8.255506   7.343539 ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [7 rows x 67 columns]

# %% [markdown]
# ## Downsample

# %%
Final = tableDF2.iloc[:,0:24]

# %%
Final.to_csv('UseMultipliedWordWeightGloveVec.csv')
